# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
pd.set_option("display.max_columns", 200)
pd.set_option('display.max_rows', 200)

# %%
features2 = pd.read_csv('X:\Chess\data\\data_dump.csv')
features2.index = features2['Date_UTC']
del features2['Date_UTC']

# %%
del features2['Date_UTC_y']

# %%
features2
# Out:
#                          Bz        By      Bx     clock        AE  SymH  \
# Date_UTC
# 2018-01-01 00:01:00 -5.0996 -4.754533  0.4300  3.891988    290.68 -4.76
# 2018-01-01 00:02:00 -4.6552 -5.393200  0.9440  4.000304    294.20 -5.96
# 2018-01-01 00:03:00 -4.5236 -5.666800  1.1748  4.038708    290.64 -6.60
# 2018-01-01 00:04:00 -4.4976 -5.764000  1.2908  4.049781    284.76 -7.08
# 2018-01-01 00:05:00 -4.5872 -5.661200  1.2852  4.031407    279.04 -7.40
# ...                     ...       ...     ...       ...       ...   ...
# 2018-12-30 23:56:00 -0.8252 -1.600000 -3.6736  4.236221 -99999.99 -7.40
# 2018-12-30 23:57:00 -0.8124 -1.620800 -3.6272  4.247755 -99999.99 -7.40
# 2018-12-30 23:58:00 -0.8092 -1.604400 -3.5644  4.245257 -99999.99 -7.36
# 2018-12-30 23:59:00 -0.8268 -1.505600 -3.5092  4.210199 -99999.99 -7.28
# 2018-12-31 00:00:00 -0.8392 -1.382400 -3.4840  4.166794 -99999.99 -7.16
#
#                             Vsw        Dsw       Psw       newell   GIC  \
# Date_UTC
# 2018-01-01 00:01:00  371.540667  13.108800  3.618600  8053.182136  0.04
# 2018-01-01 00:02:00  372.138667  13.232800  3.663000  7734.425453  0.05
# 2018-01-01 00:03:00  372.732000  13.196400  3.664600  7677.776495  0.00
# 2018-01-01 00:04:00  373.162000  13.187500  3.670800  7689.198281 -0.06
# 2018-01-01 00:05:00  373.680000  13.194000  3.683200  7777.311489 -0.06
# ...                         ...        ...       ...          ...   ...
# 2018-12-30 23:56:00  519.533333   4.503667  2.430333  7011.711031  0.08
# 2018-12-30 23:57:00  519.362667   4.508733  2.431933  6902.123757  0.01
# 2018-12-30 23:58:00  519.189333   4.516600  2.434600  6841.048202  0.04
# 2018-12-30 23:59:00  519.021333   4.533000  2.442067  6933.948701  0.07
# 2018-12-31 00:00:00  519.176000   4.567000  2.462200  7091.322949  0.03
#
#                      GIC_QDC      STD  Points  Quality  NO._IMF_AVG__x  \
# Date_UTC
# 2018-01-01 00:01:00      NaN      NaN     NaN        0             NaN
# 2018-01-01 00:02:00      NaN      NaN     NaN        0             NaN
# 2018-01-01 00:03:00      NaN      NaN     NaN        0             NaN
# 2018-01-01 00:04:00      NaN      NaN     NaN        0             NaN
# 2018-01-01 00:05:00 -0.01556  0.07343  1800.0        0             NaN
# ...                      ...      ...     ...      ...             ...
# 2018-12-30 23:56:00  0.01389  0.05308  2034.0        0             1.0
# 2018-12-30 23:57:00  0.01397  0.05311  2034.0        0             2.0
# 2018-12-30 23:58:00  0.01404  0.05313  1643.0        0             2.0
# 2018-12-30 23:59:00  0.01411  0.05316  1643.0        0             8.0
# 2018-12-31 00:00:00  0.01599  0.05400  1643.0        0             8.0
#
#                      NO._IP_PLASMA_AVG__x  RMS__PHASE_FRONT_NORMAL_nT  \
# Date_UTC
# 2018-01-01 00:01:00                   NaN                         NaN
# 2018-01-01 00:02:00                   NaN                         NaN
# 2018-01-01 00:03:00                   NaN                         NaN
# 2018-01-01 00:04:00                   NaN                         NaN
# 2018-01-01 00:05:00                   NaN                         NaN
# ...                                   ...                         ...
# 2018-12-30 23:56:00                   1.0                        0.00
# 2018-12-30 23:57:00                   1.0                        0.00
# 2018-12-30 23:58:00                 999.0                        0.00
# 2018-12-30 23:59:00                   1.0                        0.00
# 2018-12-31 00:00:00                   2.0                        0.01
#
#                      MAG_AVG_B-VECTOR_nT_x  BX__GSE_nT_x  BY__GSE_nT_x  \
# Date_UTC
# 2018-01-01 00:01:00                    NaN           NaN           NaN
# 2018-01-01 00:02:00                    NaN           NaN           NaN
# 2018-01-01 00:03:00                    NaN           NaN           NaN
# 2018-01-01 00:04:00                    NaN           NaN           NaN
# 2018-01-01 00:05:00                    NaN           NaN           NaN
# ...                                    ...           ...           ...
# 2018-12-30 23:56:00                   4.16         -3.75         -1.78
# 2018-12-30 23:57:00                   4.17         -3.62         -2.01
# 2018-12-30 23:58:00                   4.10         -3.59         -1.92
# 2018-12-30 23:59:00                   4.17         -3.53         -2.18
# 2018-12-31 00:00:00                   4.08         -3.50         -2.07
#
#                      BZ__GSE_nT_x  BY__GSM_nT_x  BZ__GSM_nT_x  \
# Date_UTC
# 2018-01-01 00:01:00           NaN           NaN           NaN
# 2018-01-01 00:02:00           NaN           NaN           NaN
# 2018-01-01 00:03:00           NaN           NaN           NaN
# 2018-01-01 00:04:00           NaN           NaN           NaN
# 2018-01-01 00:05:00           NaN           NaN           NaN
# ...                           ...           ...           ...
# 2018-12-30 23:56:00         -0.30         -1.65         -0.72
# 2018-12-30 23:57:00         -0.39         -1.85         -0.87
# 2018-12-30 23:58:00         -0.40         -1.77         -0.85
# 2018-12-30 23:59:00         -0.24         -2.06         -0.76
# 2018-12-31 00:00:00         -0.23         -1.95         -0.73
#
#                      RMS_SD_B_SCALAR_nT_x  RMS_SD_FIELD_VECTOR_nT_x  \
# Date_UTC
# 2018-01-01 00:01:00                   NaN                       NaN
# 2018-01-01 00:02:00                   NaN                       NaN
# 2018-01-01 00:03:00                   NaN                       NaN
# 2018-01-01 00:04:00                   NaN                       NaN
# 2018-01-01 00:05:00                   NaN                       NaN
# ...                                   ...                       ...
# 2018-12-30 23:56:00                  0.00                      0.00
# 2018-12-30 23:57:00                  0.02                      0.05
# 2018-12-30 23:58:00                  0.02                      0.05
# 2018-12-30 23:59:00                  0.05                      0.27
# 2018-12-31 00:00:00                  0.05                      0.19
#
#                      FLOW_SPEED__GSE_km/s_x  VX_VELOCITY__GSE_km/s_x  \
# Date_UTC
# 2018-01-01 00:01:00                     NaN                      NaN
# 2018-01-01 00:02:00                     NaN                      NaN
# 2018-01-01 00:03:00                     NaN                      NaN
# 2018-01-01 00:04:00                     NaN                      NaN
# 2018-01-01 00:05:00                     NaN                      NaN
# ...                                     ...                      ...
# 2018-12-30 23:56:00                   523.5                   -523.0
# 2018-12-30 23:57:00                   523.5                   -523.0
# 2018-12-30 23:58:00                 99999.9                  99999.9
#                      1AU_PROTONS>30_MEV_1/(SQcm-ster-s)_y  \
# Date_UTC
# 2018-12-30 23:56:00                                  0.17
# 2018-12-30 23:57:00                                  0.17
# 2018-12-30 23:58:00                                  0.17
# 2018-12-30 23:59:00                                  0.17
# 2018-12-31 00:00:00                                  0.17
#
#                      1AU_PROTONS>60_MEV_1/(SQcm-ster-s)_y  \
# Date_UTC
# 2018-12-30 23:56:00                                  0.13
# 2018-12-30 23:57:00                                  0.13
# 2018-12-30 23:58:00                                  0.13
# 2018-12-30 23:59:00                                  0.13
# 2018-12-31 00:00:00                                  0.13
#
#                      DAILY_SUNSPOT_NO__y  DAILY_F10.7__y  3-H_KP*10__y  \
# Date_UTC
# 2018-12-30 23:56:00                 13.0            -2.0         183.0
# 2018-12-30 23:57:00                 13.0            -2.0          35.0
# 2018-12-30 23:58:00                 13.0            -2.0          38.0
# 2018-12-30 23:59:00                 13.0            -2.0         259.0
# 2018-12-31 00:00:00                 13.0            -2.0          37.0
#
#                      1-H_DST_nT_y  1-H_AE_nT_y  3-H_AP_nT_y  \
# Date_UTC
# 2018-12-30 23:56:00           5.0         -7.0         45.0
# 2018-12-30 23:57:00           5.0        -32.0         37.0
# 2018-12-30 23:58:00           5.0        -21.0         21.0
# 2018-12-30 23:59:00           5.0        -13.0         31.0
# 2018-12-31 00:00:00           5.0        -26.0          1.0
#
#                      1-H_AL-INDEX_nT_y  AU-INDEX_nT_y_y  1-H_PC(N)-INDEX__y  \
# Date_UTC
# 2018-12-30 23:56:00                0.6         0.006038              0.0044
# 2018-12-30 23:57:00                0.6         0.006038              0.0044
# 2018-12-30 23:58:00                0.6         0.006038              0.0044
# 2018-12-30 23:59:00                0.6         0.006038              0.0044
# 2018-12-31 00:00:00                0.6         0.006038              0.0044
#
#                      dbz_nez_y   db_diff
# Date_UTC
# 2018-12-30 23:56:00        1.3  0.412311
# 2018-12-30 23:57:00        1.4  0.360555
# 2018-12-30 23:58:00        1.3  0.412311
# 2018-12-30 23:59:00        1.4  0.300000
# 2018-12-31 00:00:00        1.5  0.300000

# %%
features2.columns
# Out:
# Index(['Bz', 'By', 'Bx', 'clock', 'AE', 'SymH', 'Vsw', 'Dsw', 'Psw', 'newell',
#        ...
#        'DAILY_F10.7__y', '3-H_KP*10__y', '1-H_DST_nT_y', '1-H_AE_nT_y',
#        '3-H_AP_nT_y', '1-H_AL-INDEX_nT_y', 'AU-INDEX_nT_y_y',
#        '1-H_PC(N)-INDEX__y', 'dbz_nez_y', 'db_diff'],
#       dtype='object', length=194)

# %% [markdown]
# #### 10 years of data when ready

# %%
# scaled
# features = pd.read_csv('X:\\data_dumps\\features.csv')
# features.index = features['Date']
# del features['Date']

# %%
features2 = pd.read_csv('X:\\data_dumps\\10years.csv')
features2['Date'] = features2['Unnamed: 0']
features2.index = features2['Date']
del features2['Date']
del features2['Unnamed: 0']

# %%
features2.head()
# Out:
#                      db_diff  DAILY_F10.7_  3-H_KP*10_  BY__GSE_nT  \
# Date
# 2009-01-01 00:00:00      NaN            -7          59        0.60
# 2009-01-01 00:01:00      0.0            -7          59        1.19
# 2009-01-01 00:02:00      0.0            -7          59        1.87
# 2009-01-01 00:03:00      0.1            -7          59        1.70
# 2009-01-01 00:04:00      0.0            -7          59        1.71
#
#                      BZ__GSE_nT  1-H_AE_nT  SYM/H_INDEX_nT  \
# Date
# 2009-01-01 00:00:00       -0.85        -33             -13
# 2009-01-01 00:01:00       -0.91        -33             -12
# 2009-01-01 00:02:00       -0.94        -33             -12
# 2009-01-01 00:03:00       -1.05        -33             -12
# 2009-01-01 00:04:00       -0.88        -33             -12
#
#                      RMS_SD_B_SCALAR_nT  RMS_SD_FIELD_VECTOR_nT  \
# Date
# 2009-01-01 00:00:00                0.00                    0.16
# 2009-01-01 00:01:00                0.07                    1.14
# 2009-01-01 00:02:00                0.01                    0.27
# 2009-01-01 00:03:00                0.00                    0.00
# 2009-01-01 00:04:00                0.02                    0.03
#
#                      VY_VELOCITY__GSE_km/s  VZ_VELOCITY__GSE_km/s  \
# Date
# 2009-01-01 00:00:00                    4.8                  -24.5
# 2009-01-01 00:01:00                   10.5                  -25.0
# 2009-01-01 00:02:00                    5.2                  -22.9
# 2009-01-01 00:03:00                    4.2                  -22.7
# 2009-01-01 00:04:00                    8.2                  -23.1
#
#                      PROTON_DENSITY_n/cc  FLOW_PRESSURE_nPa  \
# Date
# 2009-01-01 00:00:00                 2.88               1.48
# 2009-01-01 00:01:00                 2.89               1.48
# 2009-01-01 00:02:00                 2.68               1.40
# 2009-01-01 00:03:00                 2.66               1.39
# 2009-01-01 00:04:00                 2.67               1.38
#
#                      ELECTRIC_FIELD_mV/m  PLASMA_BETA_  ALFVEN_MACH_NO._  \
# Date
# 2009-01-01 00:00:00               999.99          1.89               9.1
# 2009-01-01 00:01:00                 0.28          1.87               9.0
# 2009-01-01 00:02:00                 0.21          1.57               8.8
# 2009-01-01 00:03:00                 0.29          1.52               8.7
# 2009-01-01 00:04:00                 0.20          1.61               8.6
#
#                      AU-INDEX_nT_y  SYM/D_INDEX_nT  ASY/D_INDEX_nT  \
# Date
# 2009-01-01 00:00:00       0.005982               0              13
# 2009-01-01 00:01:00       0.005982               0              13
# 2009-01-01 00:02:00       0.005982               0              14
# 2009-01-01 00:03:00       0.005982               0              15
# 2009-01-01 00:04:00       0.005982               0              15
#
#                      ASY/H_INDEX_nT  RMSDEV_MAG_AVG_B_nT
# Date
# 2009-01-01 00:00:00              12                  0.3
# 2009-01-01 00:01:00              12                  0.3
# 2009-01-01 00:02:00              12                  0.3
# 2009-01-01 00:03:00              12                  0.3
# 2009-01-01 00:04:00              12                  0.3

# %%
# cols = list(features.columns.values)
# cols

# %%
# df = features2[[
#  'db_diff',
#  'NO._IMF_AVG__x',
#  'NO._IP_PLASMA_AVG__x',
#  'BX__GSE_nT_x',
#  'BY__GSE_nT_x',
#  'BZ__GSE_nT_x',
#  'BY__GSM_nT_x',
#  'BZ__GSM_nT_x',
#  'RMS_SD_B_SCALAR_nT_x',
#  'RMS_SD_FIELD_VECTOR_nT_x',
#  'VY_VELOCITY__GSE_km/s_x',
#  'VZ_VELOCITY__GSE_km/s_x',
#  'PROTON_DENSITY_n/cc_x',
#  'TEMPERATURE_K_x',
#  'NA/NP_RATIO__x',
#  'FLOW_PRESSURE_nPa_x',
#  'ELECTRIC_FIELD_mV/m_x',
#  'PLASMA_BETA__x',
#  'ALFVEN_MACH_NO.__x',
#  'Y_(S/C)__GSE_Re_x',
#  'Z_(S/C)__GSE_Re_x',
#  'Y_(BSN)__GSE_Re_x',
#  'Z_(BSN)__GSE_Re_x',
#  '1-M_AE_nT_x',
#  '1-M_AL-INDEX_nT_x',
#  'AU-INDEX_nT_x_x',
#  'SYM/D_INDEX_nT_x',
#  'ASY/D_INDEX_nT_x',
#  'ASY/H_INDEX_nT_x',
#  '1AU_IP_LAT/THETA_AVG_B_Deg_y',
#  '1AU_IP_LONG/PHI_AVG_B_Deg_y',
#  '1AU_IP_BX__GSE_nT_y',
#  '1AU_IP_BY__GSM_nT_y',
#  'RMSDEV_MAG_AVG_B_nT_y',
#  'RMSDEV_BX_GSE_nT_y',
#  'RMSDEV_BY_GSE_nT_y',
#  'RMSDEV_BZ_GSE_nT_y',
#  '1AU_IP_PLASMA_TEMP_Deg_K_y',
#  '1AU_IP_N_(ION)_Per_cc_y',
#  '1AU_IP_FLOW_LONG_Deg_y',
#  '1AU_IP_FLOW_LAT_Deg_y',
#  '1AU_IP_ALPHA/PROTON__y',
#  'RMSDEV_TEMP_Deg_K_y',
#  'RMSDEV_N(ION)_Per_cc_y',
#  'RMSDEV_SPEED_Km/s_y',
#  'RMSDEV_FLOW_LONG_Deg_y',
#  'RMSDEV_FLOW_LAT_Deg_y',
#  'RMSDEV_A/P_RATIO__y',
#  '1AU_IP_ELECTRIC_FIELD_mV/m_y',
#  '1AU_IP_PLASMA_BETA__y',
#  '1AU_PROTONS>10_MEV_1/(SQcm-ster-s)_y',
#  '1AU_PROTONS>30_MEV_1/(SQcm-ster-s)_y',
#  '1AU_PROTONS>60_MEV_1/(SQcm-ster-s)_y',
#  'DAILY_F10.7__y',
#  '3-H_KP*10__y',
#  '1-H_DST_nT_y',
#  '1-H_AE_nT_y',
#  '3-H_AP_nT_y',
#  '1-H_AL-INDEX_nT_y',
#  '1-H_PC(N)-INDEX__y']]

# %%
list(features2.columns)
# Out:
# ['db_diff',
#  'DAILY_F10.7_',
#  '3-H_KP*10_',
#  'BY__GSE_nT',
#  'BZ__GSE_nT',
#  '1-H_AE_nT',
#  'SYM/H_INDEX_nT',
#  'RMS_SD_B_SCALAR_nT',
#  'RMS_SD_FIELD_VECTOR_nT',
#  'VY_VELOCITY__GSE_km/s',
#  'VZ_VELOCITY__GSE_km/s',
#  'PROTON_DENSITY_n/cc',
#  'FLOW_PRESSURE_nPa',
#  'ELECTRIC_FIELD_mV/m',
#  'PLASMA_BETA_',
#  'ALFVEN_MACH_NO._',
#  'AU-INDEX_nT_y',
#  'SYM/D_INDEX_nT',
#  'ASY/D_INDEX_nT',
#  'ASY/H_INDEX_nT',
#  'RMSDEV_MAG_AVG_B_nT']

# %%
df = features2[['db_diff',
 'DAILY_F10.7_',
 '3-H_KP*10_',
 'BY__GSE_nT',
 'BZ__GSE_nT',
 '1-H_AE_nT',
 'SYM/H_INDEX_nT',
 'RMS_SD_B_SCALAR_nT',
 'RMS_SD_FIELD_VECTOR_nT',
 'VY_VELOCITY__GSE_km/s',
 'VZ_VELOCITY__GSE_km/s',
 'PROTON_DENSITY_n/cc',
 'FLOW_PRESSURE_nPa',
 'ELECTRIC_FIELD_mV/m',
 'PLASMA_BETA_',
 'ALFVEN_MACH_NO._',
 'AU-INDEX_nT_y',
 'SYM/D_INDEX_nT',
 'ASY/D_INDEX_nT',
 'ASY/H_INDEX_nT',
 'RMSDEV_MAG_AVG_B_nT']]

# %%
df = features2[['db_diff','DAILY_F10.7__y',
'3-H_KP*10__y',
'BY__GSE_nT_y',
'BZ__GSE_nT_y',
'1-H_AE_nT_y',
'SYM/H_INDEX_nT_y',
'RMS_SD_B_SCALAR_nT_y',
'RMS_SD_FIELD_VECTOR_nT_y',
'VY_VELOCITY__GSE_km/s_y',
'VZ_VELOCITY__GSE_km/s_y',
'PROTON_DENSITY_n/cc_y',
'FLOW_PRESSURE_nPa_y',
'ELECTRIC_FIELD_mV/m_y',
'PLASMA_BETA__y',
'ALFVEN_MACH_NO.__y',
'AU-INDEX_nT_y_y',
'SYM/D_INDEX_nT_y',
'ASY/D_INDEX_nT_y',
'ASY/H_INDEX_nT_y',  
'RMSDEV_MAG_AVG_B_nT_y']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-154-3cf31eb7ed7a> in <module>
#      18 'ASY/D_INDEX_nT_y',
#      19 'ASY/H_INDEX_nT_y',
# ---> 20 'RMSDEV_MAG_AVG_B_nT_y']]
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['DAILY_F10.7__y', '3-H_KP*10__y', 'BY__GSE_nT_y', 'BZ__GSE_nT_y', '1-H_AE_nT_y', 'SYM/H_INDEX_nT_y', 'RMS_SD_B_SCALAR_nT_y', 'RMS_SD_FIELD_VECTOR_nT_y', 'VY_VELOCITY__GSE_km/s_y', 'VZ_VELOCITY__GSE_km/s_y', 'PROTON_DENSITY_n/cc_y', 'FLOW_PRESSURE_nPa_y', 'ELECTRIC_FIELD_mV/m_y', 'PLASMA_BETA__y', 'ALFVEN_MACH_NO.__y', 'AU-INDEX_nT_y_y', 'SYM/D_INDEX_nT_y', 'ASY/D_INDEX_nT_y', 'ASY/H_INDEX_nT_y', 'RMSDEV_MAG_AVG_B_nT_y'] not in index"

# %%
# df = features2[['db_diff','DAILY_F10.7__x',
# '3-H_KP*10__x', 
# 'By',
# 'Bz',
# 'AE',
# 'SymH',
# 'Vsw',
# 'Dsw',
# 'Psw',
# 'newell',
# 'RMS_SD_B_SCALAR_nT_y',
# 'RMS_SD_FIELD_VECTOR_nT_y',
# 'VY_VELOCITY__GSE_km/s_y',
# 'VZ_VELOCITY__GSE_km/s_y',
# 'PROTON_DENSITY_n/cc_y',
# 'FLOW_PRESSURE_nPa_y',
# 'ELECTRIC_FIELD_mV/m_y',
# 'PLASMA_BETA__y',
# 'ALFVEN_MACH_NO.__y',
# 'AU-INDEX_nT_y_y',
# 'SYM/D_INDEX_nT_y',
# 'ASY/D_INDEX_nT_y',
# 'ASY/H_INDEX_nT_y',  
# 'RMSDEV_MAG_AVG_B_nT_y']]

# %%
# df.to_csv('X:\Chess\data\\data_for_Chris.csv')

# %%
# df = features2[['db_diff','DAILY_F10.7__x',
# '3-H_KP*10__x', 
# 'BY__GSM_nT_x',
# 'BZ__GSM_nT_x',
# 'RMS_SD_B_SCALAR_nT_x',
# 'RMS_SD_FIELD_VECTOR_nT_x',
# 'VY_VELOCITY__GSE_km/s_x',
# 'VZ_VELOCITY__GSE_km/s_x',
# 'PROTON_DENSITY_n/cc_x',
# 'FLOW_PRESSURE_nPa_x',
# 'ELECTRIC_FIELD_mV/m_x',
# 'PLASMA_BETA__x',
# 'ALFVEN_MACH_NO.__x',
# 'AU-INDEX_nT_x_x',
# 'SYM/D_INDEX_nT_x',
# 'ASY/D_INDEX_nT_x',
# 'ASY/H_INDEX_nT_x',  
# 'RMSDEV_MAG_AVG_B_nT_x',
# 'states']]

# %%
# df = features[['db_diff','DAILY_F10.7_',
# '3-H_KP*10_', 
# 'BY__GSM_nT',
# 'BZ__GSM_nT',
# 'RMS_SD_B_SCALAR_nT',
# 'RMS_SD_FIELD_VECTOR_nT',
# 'VY_VELOCITY__GSE_km/s',
# 'VZ_VELOCITY__GSE_km/s',
# 'PROTON_DENSITY_n/cc',
# 'FLOW_PRESSURE_nPa',
# 'ELECTRIC_FIELD_mV/m',
# 'PLASMA_BETA_',
# 'ALFVEN_MACH_NO._',
# 'AU-INDEX_nT_x',
# 'SYM/D_INDEX_nT',
# 'ASY/D_INDEX_nT',
# 'ASY/H_INDEX_nT',  
# 'RMSDEV_MAG_AVG_B_nT',
# 'states']]

# %%
df.head(5)
# Out:
#                      db_diff  DAILY_F10.7_  3-H_KP*10_  BY__GSE_nT  \
# Date
# 2009-01-01 00:00:00      NaN            -7          59        0.60
# 2009-01-01 00:01:00      0.0            -7          59        1.19
# 2009-01-01 00:02:00      0.0            -7          59        1.87
# 2009-01-01 00:03:00      0.1            -7          59        1.70
# 2009-01-01 00:04:00      0.0            -7          59        1.71
#
#                      BZ__GSE_nT  1-H_AE_nT  SYM/H_INDEX_nT  \
# Date
# 2009-01-01 00:00:00       -0.85        -33             -13
# 2009-01-01 00:01:00       -0.91        -33             -12
# 2009-01-01 00:02:00       -0.94        -33             -12
# 2009-01-01 00:03:00       -1.05        -33             -12
# 2009-01-01 00:04:00       -0.88        -33             -12
#
#                      RMS_SD_B_SCALAR_nT  RMS_SD_FIELD_VECTOR_nT  \
# Date
# 2009-01-01 00:00:00                0.00                    0.16
# 2009-01-01 00:01:00                0.07                    1.14
# 2009-01-01 00:02:00                0.01                    0.27
# 2009-01-01 00:03:00                0.00                    0.00
# 2009-01-01 00:04:00                0.02                    0.03
#
#                      VY_VELOCITY__GSE_km/s  VZ_VELOCITY__GSE_km/s  \
# Date
# 2009-01-01 00:00:00                    4.8                  -24.5
# 2009-01-01 00:01:00                   10.5                  -25.0
# 2009-01-01 00:02:00                    5.2                  -22.9
# 2009-01-01 00:03:00                    4.2                  -22.7
# 2009-01-01 00:04:00                    8.2                  -23.1
#
#                      PROTON_DENSITY_n/cc  FLOW_PRESSURE_nPa  \
# Date
# 2009-01-01 00:00:00                 2.88               1.48
# 2009-01-01 00:01:00                 2.89               1.48
# 2009-01-01 00:02:00                 2.68               1.40
# 2009-01-01 00:03:00                 2.66               1.39
# 2009-01-01 00:04:00                 2.67               1.38
#
#                      ELECTRIC_FIELD_mV/m  PLASMA_BETA_  ALFVEN_MACH_NO._  \
# Date
# 2009-01-01 00:00:00               999.99          1.89               9.1
# 2009-01-01 00:01:00                 0.28          1.87               9.0
# 2009-01-01 00:02:00                 0.21          1.57               8.8
# 2009-01-01 00:03:00                 0.29          1.52               8.7
# 2009-01-01 00:04:00                 0.20          1.61               8.6
#
#                      AU-INDEX_nT_y  SYM/D_INDEX_nT  ASY/D_INDEX_nT  \
# Date
# 2009-01-01 00:00:00       0.005982               0              13
# 2009-01-01 00:01:00       0.005982               0              13
# 2009-01-01 00:02:00       0.005982               0              14
# 2009-01-01 00:03:00       0.005982               0              15
# 2009-01-01 00:04:00       0.005982               0              15
#
#                      ASY/H_INDEX_nT  RMSDEV_MAG_AVG_B_nT
# Date
# 2009-01-01 00:00:00              12                  0.3
# 2009-01-01 00:01:00              12                  0.3
# 2009-01-01 00:02:00              12                  0.3
# 2009-01-01 00:03:00              12                  0.3
# 2009-01-01 00:04:00              12                  0.3

# %% [markdown]
# ###### Lets add some lagging variables

# %%
df['db_diff_lag'] = df['db_diff'].shift(0)
df.db_diff_lag.fillna(0, inplace=True)

# %%
# df['db_diff_lag3'] = df['db_diff'].shift(3)
# df.db_diff_lag3.fillna(0, inplace=True)
# df['db_diff_lag4'] = df['db_diff'].shift(4)
# df.db_diff_lag4.fillna(0, inplace=True)
# df['db_diff_lag5'] = df['db_diff'].shift(5)
# df.db_diff_lag5.fillna(0, inplace=True)

# %%
df['db_diff_lag2'] = df['db_diff'].shift(2)
df.db_diff_lag2.fillna(0, inplace=True)

# %%
train, val_df, test = np.split(features.sample(frac=1), [int(.6*len(features)), int(.8*len(features))])

# %%
# # split into train and test sets
# train_size = int(len(features) * 0.67)
# test_size = len(features) - train_size
# train, test = features[0:train_size,:], features[train_size:len(features),:]
# print(len(train), len(test))

# %%
# create and fit the LSTM network
# model = Sequential()
# model.add(LSTM(4, input_shape=(1, look_back)))
# model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='adam')
# model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# %%
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# // pseudo code
# x = conv2d(x, filters=32, kernel=[3,3])->batch_norm()->relu()
# x = conv2d(x, filters=32, kernel=[3,3])->batch_norm()->relu()
# x = conv2d(x, filters=32, kernel=[3,3])->batch_norm()->relu()
# x = maxpool(x, size=[2,2], stride=[2,2])

# x = conv2d(x, filters=64, kernel=[3,3])->batch_norm()->relu()
# x = conv2d(x, filters=64, kernel=[3,3])->batch_norm()->relu()
# x = conv2d(x, filters=64, kernel=[3,3])->batch_norm()->relu()
# x = maxpool(x, size=[2,2], stride=[2,2])

# x = conv2d(x, filters=128, kernel=[3,3])->batch_norm()->relu()
# x = conv2d(x, filters=128, kernel=[3,3])->batch_norm()->relu()
# x = conv2d(x, filters=128, kernel=[3,3])->batch_norm()->relu()
# x = maxpool(x, size=[2,2], stride=[2,2])

# x = dropout()->conv2d(x, filters=128, kernel=[1, 1])->batch_norm()->relu()
# x = dropout()->conv2d(x, filters=32, kernel=[1, 1])->batch_norm()->relu()

# y = dense(x, units=1)

# // loss = mean_squared_error(y, labels)

# %%
df.shape
# Out:
# (510998, 21)

# %%
df = df.replace([99999.9, 9999.99, 999.99, 999999.0 ,999999.00,-99999.990000,-99999.990000,9.999000,10000000.0,999.99,99.9,9999.99,999,9999.0,99999,999.9,99.99, '#REF!', np.nan],0)

# %%
df
# Out:
#                       db_diff  DAILY_F10.7_  3-H_KP*10_  BY__GSE_nT  \
# Date
# 2009-01-01 00:00:00  0.000000            -7          59        0.60
# 2009-01-01 00:01:00  0.000000            -7          59        1.19
# 2009-01-01 00:02:00  0.000000            -7          59        1.87
# 2009-01-01 00:03:00  0.100000            -7          59        1.70
# 2009-01-01 00:04:00  0.000000            -7          59        1.71
# ...                       ...           ...         ...         ...
# 2020-12-30 23:56:00  0.316228            -4           0       -2.31
# 2020-12-30 23:57:00  0.412311            -4           0       -2.31
# 2020-12-30 23:58:00  0.400000            -4           0        0.00
# 2020-12-30 23:59:00  0.583095            -4           0       -2.27
# 2020-12-31 00:00:00  0.600000            -4           0        0.00
#
#                      BZ__GSE_nT  1-H_AE_nT  SYM/H_INDEX_nT  \
# Date
# 2009-01-01 00:00:00       -0.85        -33             -13
# 2009-01-01 00:01:00       -0.91        -33             -12
# 2009-01-01 00:02:00       -0.94        -33             -12
# 2009-01-01 00:03:00       -1.05        -33             -12
# 2009-01-01 00:04:00       -0.88        -33             -12
# ...                         ...        ...             ...
# 2020-12-30 23:56:00       -1.99          0              -7
# 2020-12-30 23:57:00       -1.99          0              -7
# 2020-12-30 23:58:00        0.00          0              -7
# 2020-12-30 23:59:00       -1.52          0              -7
# 2020-12-31 00:00:00        0.00          0              -8
#
#                      RMS_SD_B_SCALAR_nT  RMS_SD_FIELD_VECTOR_nT  \
# Date
# 2009-01-01 00:00:00                0.00                    0.16
# 2009-01-01 00:01:00                0.07                    1.14
# 2009-01-01 00:02:00                0.01                    0.27
# 2009-01-01 00:03:00                0.00                    0.00
# 2009-01-01 00:04:00                0.02                    0.03
# ...                                 ...                     ...
# 2020-12-30 23:56:00                0.00                    0.00
# 2020-12-30 23:57:00                0.00                    0.00
# 2020-12-30 23:58:00                0.00                    0.00
# 2020-12-30 23:59:00                0.00                    0.00
# 2020-12-31 00:00:00                0.00                    0.00
#
#                      VY_VELOCITY__GSE_km/s  VZ_VELOCITY__GSE_km/s  \
# Date
# 2009-01-01 00:00:00                    4.8                  -24.5
# 2009-01-01 00:01:00                   10.5                  -25.0
# 2009-01-01 00:02:00                    5.2                  -22.9
# 2009-01-01 00:03:00                    4.2                  -22.7
# 2009-01-01 00:04:00                    8.2                  -23.1
# ...                                    ...                    ...
# 2020-12-30 23:56:00                   -3.2                  -20.2
# 2020-12-30 23:57:00                   -3.2                  -20.2
# 2020-12-30 23:58:00                   -3.2                  -20.2
# 2020-12-30 23:59:00                    0.0                    0.0
# 2020-12-31 00:00:00                    0.0                    0.0
#
#                      PROTON_DENSITY_n/cc  FLOW_PRESSURE_nPa  \
# Date
# 2009-01-01 00:00:00                 2.88               1.48
# 2009-01-01 00:01:00                 2.89               1.48
# 2009-01-01 00:02:00                 2.68               1.40
# 2009-01-01 00:03:00                 2.66               1.39
# 2009-01-01 00:04:00                 2.67               1.38
# ...                                  ...                ...
# 2020-12-30 23:56:00                 2.50               1.02
# 2020-12-30 23:57:00                 2.50               1.02
# 2020-12-30 23:58:00                 2.50               1.02
# 2020-12-30 23:59:00                 0.00               0.00
# 2020-12-31 00:00:00                 0.00               0.00
#
#                      ELECTRIC_FIELD_mV/m  PLASMA_BETA_  ALFVEN_MACH_NO._  \
# Date
# 2009-01-01 00:00:00                 0.00          1.89               9.1
# 2009-01-01 00:01:00                 0.28          1.87               9.0
# 2009-01-01 00:02:00                 0.21          1.57               8.8
# 2009-01-01 00:03:00                 0.29          1.52               8.7
# 2009-01-01 00:04:00                 0.20          1.61               8.6
# ...                                  ...           ...               ...
# 2020-12-30 23:56:00                 1.13          1.83              11.0
# 2020-12-30 23:57:00                 1.13          1.83              11.0
# 2020-12-30 23:58:00                 0.00          0.00               0.0
# 2020-12-30 23:59:00                 0.00          0.00               0.0
# 2020-12-31 00:00:00                 0.00          0.00               0.0
#
#                      AU-INDEX_nT_y  SYM/D_INDEX_nT  ASY/D_INDEX_nT  \
# Date
# 2009-01-01 00:00:00       0.005982               0              13
# 2009-01-01 00:01:00       0.005982               0              13
# 2009-01-01 00:02:00       0.005982               0              14
# 2009-01-01 00:03:00       0.005982               0              15
# 2009-01-01 00:04:00       0.005982               0              15
# ...                            ...             ...             ...
# 2020-12-30 23:56:00       0.006873              -1              17
# 2020-12-30 23:57:00       0.006873               0              16
# 2020-12-30 23:58:00       0.006873               0              16
# 2020-12-30 23:59:00       0.006873              -1              16
# 2020-12-31 00:00:00       0.006873               0              15
#
#                      ASY/H_INDEX_nT  RMSDEV_MAG_AVG_B_nT
# Date
# 2009-01-01 00:00:00              12                  0.3
# 2009-01-01 00:01:00              12                  0.3
# 2009-01-01 00:02:00              12                  0.3
# 2009-01-01 00:03:00              12                  0.3
# 2009-01-01 00:04:00              12                  0.3
# ...                             ...                  ...
# 2020-12-30 23:56:00              13                  0.2
# 2020-12-30 23:57:00              13                  0.2
# 2020-12-30 23:58:00              12                  0.2
# 2020-12-30 23:59:00              12                  0.2
# 2020-12-31 00:00:00              11                  0.2
#
# [6831364 rows x 21 columns]

# %% [markdown]
# ### Normalize Data

# %%
import seaborn as sns
from scipy.stats import norm
from scipy import stats

# %%
data_list = list(df.columns)

# %%
#histogram and normal probability plot
sns.distplot(df[df['BZ__GSE_nT']>0]['BZ__GSE_nT'], fit=norm);
fig = plt.figure()
res = stats.probplot(df[df['BZ__GSE_nT']>0]['BZ__GSE_nT'], plot=plt)
# Out:
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Box Cox neeeds the min value to be zero

# %%
df.columns
columns = ['db_diff', 'DAILY_F10.7_', '3-H_KP*10_', 'BY__GSE_nT', 'BZ__GSE_nT',
       '1-H_AE_nT', 'SYM/H_INDEX_nT', 'RMS_SD_B_SCALAR_nT',
       'RMS_SD_FIELD_VECTOR_nT', 'VY_VELOCITY__GSE_km/s',
       'VZ_VELOCITY__GSE_km/s', 'PROTON_DENSITY_n/cc', 'FLOW_PRESSURE_nPa',
       'ELECTRIC_FIELD_mV/m', 'PLASMA_BETA_', 'ALFVEN_MACH_NO._',
       'AU-INDEX_nT_y', 'SYM/D_INDEX_nT', 'ASY/D_INDEX_nT', 'ASY/H_INDEX_nT',
       'RMSDEV_MAG_AVG_B_nT']

# %%
df.columns
columns = ['DAILY_F10.7__y', '3-H_KP*10__y', 'BY__GSE_nT_y',
       'BZ__GSE_nT_y', '1-H_AE_nT_y', 'SYM/H_INDEX_nT_y',
       'RMS_SD_B_SCALAR_nT_y', 'RMS_SD_FIELD_VECTOR_nT_y',
       'VY_VELOCITY__GSE_km/s_y', 'VZ_VELOCITY__GSE_km/s_y',
       'PROTON_DENSITY_n/cc_y', 'FLOW_PRESSURE_nPa_y', 'ELECTRIC_FIELD_mV/m_y',
       'PLASMA_BETA__y', 'ALFVEN_MACH_NO.__y', 'AU-INDEX_nT_y_y',
       'SYM/D_INDEX_nT_y', 'ASY/D_INDEX_nT_y', 'ASY/H_INDEX_nT_y',
       'RMSDEV_MAG_AVG_B_nT_y']

# %%
# columns = df.columns

for column in df:
    min_value_for_column = df[column].min()
    if min_value_for_column < 0:
        df[column] = df[column] + abs(min_value_for_column)

# %%
# apply box Cox

# %%
def box_cox(df, column_name):
    for column in column_name:
        df[column] = stats.boxcox(df[column] + 1)[0]
    return df

# %%
df = box_cox(df,columns)
df.describe()
# Out:
#             db_diff  DAILY_F10.7_    3-H_KP*10_    BY__GSE_nT    BZ__GSE_nT  \
# count  6.831364e+06  6.831364e+06  6.831364e+06  6.831364e+06  6.831364e+06
# mean   2.006250e-01  3.542408e+11  5.733432e+00  2.106183e+01  7.529808e+01
# std    1.385522e-01  1.101445e+11  3.764303e+00  1.812278e+00  6.241017e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    8.740982e-02  2.902903e+11  3.840648e+00  1.993038e+01  7.226849e+01
# 50%    1.997451e-01  3.622258e+11  5.943127e+00  2.112640e+01  7.524990e+01
# 75%    3.099193e-01  4.276166e+11  8.380371e+00  2.218582e+01  7.827466e+01
# max    5.423472e-01  1.971043e+12  1.656041e+01  4.001938e+01  1.681630e+02
#
#           1-H_AE_nT  SYM/H_INDEX_nT  RMS_SD_B_SCALAR_nT  \
# count  6.831364e+06    6.831364e+06        6.831364e+06
# mean   1.509147e+46    5.465588e+10        3.062823e-02
# std    7.328496e+45    1.484808e+10        2.985895e-02
# min    0.000000e+00    0.000000e+00        0.000000e+00
# 25%    9.561149e+45    4.648855e+10        0.000000e+00
# 50%    1.776666e+46    5.527481e+10        2.534372e-02
# 75%    2.178680e+46    6.399966e+10        5.245471e-02
# max    2.569082e+46    7.091106e+11        9.353553e-02
#
#        RMS_SD_FIELD_VECTOR_nT  VY_VELOCITY__GSE_km/s  VZ_VELOCITY__GSE_km/s
'3-H_KP*10__y',
'BY__GSE_nT_y',
'BZ__GSE_nT_y',
'1-H_AE_nT_y',
'SYM/H_INDEX_nT_y',
'RMS_SD_B_SCALAR_nT_y',
'RMS_SD_FIELD_VECTOR_nT_y',
'VY_VELOCITY__GSE_km/s_y',
'VZ_VELOCITY__GSE_km/s_y',
'PROTON_DENSITY_n/cc_y',
'FLOW_PRESSURE_nPa_y',
'ELECTRIC_FIELD_mV/m_y',
'PLASMA_BETA__y',
'ALFVEN_MACH_NO.__y',
'AU-INDEX_nT_y_y',
'SYM/D_INDEX_nT_y',
'ASY/D_INDEX_nT_y',
'ASY/H_INDEX_nT_y',  
'RMSDEV_MAG_AVG_B_nT_y']]

# %%
# columns = df.columns.tolist() #['Bz', 'By', 'Bx', 'clock', 'Vsw', 'Dsw', 'Psw', 'newell', 'AE']
# for x in columns:
#     #fill in missing values using probabilities and weighted values
#     try:
#         s = df[x].value_counts(normalize=True)
#         missing = df[x].isnull()
#         df.loc[missing,x] = np.random.choice(s.index, size=len(df[missing]),p=s.values)
#     except ValueError:
#         pass

# %%
# input_layer = Input(shape=(19), dtype='float32')
# dense1 = Dense(1, activation='linear')(input_layer)
# dropout_layer1 = Dropout(0.1)(dense1)
# # dense2 = Dense(1, activation='linear')(dropout_layer1)
# # dropout_layer2 = Dropout(0.1)(dense2)
# output_layer = Dense(1, activation='linear')(dropout_layer1)

# %%
# model = Model(inputs=input_layer, outputs=output_layer)
# model.compile(loss='mean_squared_error', optimizer='adam')
# model.summary()

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
# !pip install graphviz
# !pip install pydot

# %%
y_test
# Out:
# 500778    0.200000
# 500779    0.200000
# 500780    0.200000
# 500781    0.223607
# 500782    0.447214
#             ...
# 510993    0.412311
# 510994    0.360555
# 510995    0.412311
# 510996    0.300000
# 510997    0.300000
# Name: db_diff, Length: 10220, dtype: float64

# %%
test_set_size = 0.02
valid_set_size= 0.20

df_copy = df5.reset_index(drop=True)

df_test = df_copy.iloc[ int(np.floor(len(df_copy)*(1-test_set_size))) : ]
df_train_plus_valid = df_copy.iloc[ : int(np.floor(len(df_copy)*(1-test_set_size))) ]

df_train = df_train_plus_valid.iloc[ : int(np.floor(len(df_train_plus_valid)*(1-valid_set_size))) ]
df_valid = df_train_plus_valid.iloc[ int(np.floor(len(df_train_plus_valid)*(1-valid_set_size))) : ]


X_train, y_train = df_train.iloc[:, 1:], df_train.iloc[:, 0]
X_valid, y_valid = df_valid.iloc[:, 1:], df_valid.iloc[:, 0]
X_test, y_test = df_test.iloc[:, 1:], df_test.iloc[:, 0]

print('Shape of training inputs, training target:', X_train.shape, y_train.shape)
print('Shape of validation inputs, validation target:', X_valid.shape, y_valid.shape)
print('Shape of test inputs, test target:', X_test.shape, y_test.shape)
# Out:
# Shape of training inputs, training target: (5355788, 20) (5355788,)
# Shape of validation inputs, validation target: (1338948, 20) (1338948,)
# Shape of test inputs, test target: (136628, 20) (136628,)

# %%
y_test
# Out:
# 6694736    0.268062
# 6694737    0.391383
# 6694738    0.367752
# 6694739    0.395419
# 6694740    0.379868
# 5355789          0.183876       0.173957        0.266557        0.464344
# 5355790          0.179126       0.173957        0.266557        0.464344
# 5355791          0.175894       0.173957        0.266557        0.464344
# 5355792          0.175077       0.173957        0.266557        0.464344
# ...                   ...            ...             ...             ...
# 6694731          0.143917       0.327013        0.285979        0.407138
# 6694732          0.144889       0.327013        0.285979        0.407138
# 6694733          0.144889       0.327013        0.285979        0.389107
# 6694734          0.000000       0.327013        0.285979        0.389107
# 6694735          0.145855       0.327013        0.285979        0.407138
#
#          ASY/H_INDEX_nT  RMSDEV_MAG_AVG_B_nT
# 5355788        0.551905             0.529725
# 5355789        0.551905             0.529725
# 5355790        0.551905             0.529725
# 5355791        0.551905             0.529725
# 5355792        0.551905             0.529725
# ...                 ...                  ...
# 6694731        0.645373             0.239644
# 6694732        0.639938             0.239644
# 6694733        0.634293             0.239644
# 6694734        0.634293             0.239644
# 6694735        0.639938             0.239644
#
# [1338948 rows x 20 columns]

# %%
# df_test

# %%
# tensorboard_callback = tensorflow.keras.callbacks.TensorBoard(log_dir="./logs")

# %%
import tensorflow as tf
import datetime, os

# %%
# def create_model():
#   return tf.keras.models.Sequential([
#     tf.keras.layers.Flatten(input_shape=(28, 28)),
#     tf.keras.layers.Dense(512, activation='relu'),
#     tf.keras.layers.Dropout(0.2),
#     tf.keras.layers.Dense(10, activation='softmax')
#   ])


# input_layer = Input(shape=(26), dtype='float32')
# dense1 = Dense(5, activation='relu')(input_layer)
# dropout_layer1 = Dropout(0.5)(dense1)
# dense2 = Dense(5, activation='relu')(dropout_layer1)
# dropout_layer2 = Dropout(0.5)(dense2)
# output_layer = Dense(1, activation='relu')(dropout_layer2)

# %%
# input_layer = Input(shape=(26), dtype='float32')
# dense1 = Dense(291, activation='relu')(input_layer)
# dropout_layer1 = Dropout(0.9)(dense1)
# dense2 = Dense(146, activation='relu')(dropout_layer1)
# dropout_layer2 = Dropout(0.9)(dense2)
# dense3 = Dense(73, activation='relu')(dropout_layer2)
# dropout_layer3 = Dropout(0.9)(dense3)
# dense4 = Dense(36, activation='relu')(dropout_layer3)
# dropout_layer4 = Dropout(0.9)(dense4)
# output_layer = Dense(1, activation='relu')(dropout_layer4)

# %%
# model = Model(inputs=input_layer, outputs=output_layer)
# model.compile(loss='mean_squared_error', optimizer='adam')
# model.summary()
# loss='mean_squared_error'
#'mean_squared_logarithmic_error'

# %%
# model = Model(inputs=input_layer, outputs=output_layer)
# model.compile(loss='mean_squared_error', optimizer='Adam', metrics=['accuracy'])
# model.summary()

# %% [markdown]
# ## -------- Saving Points

# %%
import os

import tensorflow as tf
from tensorflow import keras

print(tf.version.VERSION)
# Out:
# 2.3.0

# %%
# input_layer = Input(shape=(26), dtype='float32')
# dense1 = Dense(291, activation='relu')(input_layer)
# dropout_layer1 = Dropout(0.9)(dense1)
# dense2 = Dense(146, activation='relu')(dropout_layer1)
# dropout_layer2 = Dropout(0.9)(dense2)
# dense3 = Dense(73, activation='relu')(dropout_layer2)
# dropout_layer3 = Dropout(0.9)(dense3)
# dense4 = Dense(36, activation='relu')(dropout_layer3)
# dropout_layer4 = Dropout(0.9)(dense4)
# output_layer = Dense(1, activation='relu')(dropout_layer4)

# %%
# !pip install -q -U keras-tuner

# %%
import keras_tuner as kt

# %%
def create_model(hp):
  model = tf.keras.Sequential()
#   model.add(keras.layers.Dense(512, input_shape=(24,)))

#   # Tune the number of units in the first Dense layer
#   # Choose an optimal value between 32-512
#   hp_units = hp.Int('units', min_value=8, max_value=512, step=32)
#   model.add(keras.layers.Dense(units=128, activation='relu'))
#   model.add(keras.layers.Dense(units=128, activation='relu'))
#   model.add(keras.layers.Dense(units=hp_units, activation='relu'))
#   model.add(keras.layers.Dense(1))


  # Tune the number of units in the first Dense layer
  # Choose an optimal value between 32-512
  hp_units1 = hp.Int('units1', min_value=8, max_value=512, step=32)
  hp_units2 = hp.Int('units2', min_value=8, max_value=512, step=32)
  hp_units3 = hp.Int('units3', min_value=8, max_value=512, step=32)
  model.add(Dense(units=hp_units1, activation='relu'))
  model.add(tf.keras.layers.Dense(units=hp_units2, activation='relu', input_shape=(24,)))
  model.add(tf.keras.layers.Dense(units=hp_units3, activation='relu'))
  model.add(Dense(1, kernel_initializer='normal', activation='linear'))
  model.add(Dense(units=hp_units1, activation='relu'))
  model.add(tf.keras.layers.Dense(units=hp_units2, activation='relu', input_shape=(24,)))
  model.add(tf.keras.layers.Dense(units=hp_units3, activation='relu'))
  model.add(Dense(1, kernel_initializer='normal', activation='linear'))

  # Tune the learning rate for the optimizer
  # Choose an optimal value from 0.01, 0.001, or 0.0001
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss='mean_squared_error',
                metrics=['accuracy'])

  return model

# %%
tuner = kt.Hyperband(create_model,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='keras_tuner_db_diff')

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x=X_train, y=y_train,batch_size=112, epochs=50, validation_data=(X_valid, y_valid),shuffle=True, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units1')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 424 and the optimal learning rate for the optimizer
# is 0.0001.

# %%
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units1')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units2')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units3')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 136 and the optimal learning rate for the optimizer
# is 0.0001.
#
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 104 and the optimal learning rate for the optimizer
# is 0.0001.
#
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 424 and the optimal learning rate for the optimizer
# is 0.0001.

# %% [markdown]
# Trial 30 Complete [00h 00m 48s]
# val_accuracy: 0.010381905362010002
#
# Best val_accuracy So Far: 0.03448275849223137
# Total elapsed time: 00h 13m 00s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 128 and the optimal learning rate for the optimizer
# is 0.001.

# %%
import keras

# %%
import keras.backend as K
def tilted_loss(q,y,f):
    e = (y-f)
    return K.mean(K.maximum(q*e, (q-1)*e), axis=-1)

quantile = 0.75
loss=lambda y,f: tilted_loss(quantile,y,f)

# %%
from keras import optimizers
sgd = optimizers.SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True)

# %%
# install numpy==1.19.5 not 1.21.0
import numpy as np

# %%
# Define a simple sequential model
def create_model():
  model = tf.keras.models.Sequential([
    keras.layers.Dense(124, activation='relu', input_shape=(20,)),
#     keras.layers.Dropout(0.1),
    keras.layers.Dense(136, activation='relu'),
#     keras.layers.Dropout(0.1),
    keras.layers.Dense(104, activation='relu'),
# #     keras.layers.Dropout(0.1),
    keras.layers.Dense(240, activation='relu'),
#     keras.layers.Dropout(0.1),
    keras.layers.Dense(64, activation='relu'),
#     keras.layers.Dropout(0.1),
    keras.layers.Dense(40, activation='relu'),
#     keras.layers.Dropout(0.1),
    keras.layers.Dense(1,kernel_initializer='normal', activation='relu')
  ])

  model.compile(optimizer=sgd,
                loss='mean_squared_error',
                metrics=['accuracy'])
  return model
#optimizer=sgd local min
#keras.optimizers.Adam(learning_rate=0.0001)
# optimizer='adam'
# Create a basic model instance
#kernel_initializer='random_normal',bias_initializer='zeros'
model = create_model()

# Display the model's architecture
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_60 (Dense)             (None, 124)               2604
# _________________________________________________________________
# dense_61 (Dense)             (None, 136)               17000
# _________________________________________________________________
# dense_62 (Dense)             (None, 104)               14248
# _________________________________________________________________
# dense_63 (Dense)             (None, 240)               25200
# _________________________________________________________________
# dense_64 (Dense)             (None, 64)                15424
# _________________________________________________________________
# dense_65 (Dense)             (None, 40)                2600
# _________________________________________________________________
# dense_66 (Dense)             (None, 1)                 41
# =================================================================
# Total params: 77,117
# Trainable params: 77,117
# Non-trainable params: 0
# _________________________________________________________________

# %%
logdir = os.path.join(r"C:\Users\cgree\Documents\logs\logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1, embeddings_freq=1)
logdir
# Out:
# 'C:\\Users\\cgree\\Documents\\logs\\logs\\20210830-120303'

# %%
#for tensorboard
(CleanTF) C:\Users\cgree\Documents\logs\logs>tensorboard --port=9007 --logdir=20210824-093730
# Out:
#   File "<ipython-input-219-9f319586c938>", line 2
#     (CleanTF) C:\Users\cgree\Documents\logs\logs>tensorboard --port=9007 --logdir=20210824-093730
#               ^
# SyntaxError: invalid syntax

# %%
# X_train

# %%
# df.hist(column='db_diff')
# df.describe()

# %%
# #Scale data
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# scaled = scaler.fit_transform(df)
# df_scaled = pd.DataFrame(scaled, columns = ['db_diff',
#  'DAILY_F10.7_','3-H_KP*10_','BY__GSE_nT','BZ__GSE_nT','1-H_AE_nT','SYM/H_INDEX_nT','RMS_SD_B_SCALAR_nT','RMS_SD_FIELD_VECTOR_nT',
#  'VY_VELOCITY__GSE_km/s','VZ_VELOCITY__GSE_km/s','PROTON_DENSITY_n/cc','FLOW_PRESSURE_nPa','ELECTRIC_FIELD_mV/m','PLASMA_BETA_',
#  'ALFVEN_MACH_NO._','AU-INDEX_nT_y','SYM/D_INDEX_nT','ASY/D_INDEX_nT','ASY/H_INDEX_nT','RMSDEV_MAG_AVG_B_nT'])

#descale data
# unscaled = scaler.inverse_transform(scaled)[:, [0]]

# %%
# df_scaled
# df_scaled.hist(column='db_diff')
# df_scaled.describe()

# %%
# #descale data
# unscaled = scaler.inverse_transform(scaled)[:, [0]]

# %%
#train from checkpoint
# model = load_model("training_1/cp.ckpt")

# %%
y_valid
# Out:
# 5355788    0.087410
# 5355789    0.168530
# 5355790    0.087410
# 5355791    0.087410
# 5355792    0.117388
#              ...
# 6694731    0.255426
# 6694732    0.168530
# 6694733    0.250754
# 6694734    0.255426
# 6694735    0.285606
# Name: db_diff, Length: 1338948, dtype: float64

# %%
X_valid.columns
# Out:
# Index(['DAILY_F10.7_', '3-H_KP*10_', 'BY__GSE_nT', 'BZ__GSE_nT', '1-H_AE_nT',
#        'SYM/H_INDEX_nT', 'RMS_SD_B_SCALAR_nT', 'RMS_SD_FIELD_VECTOR_nT',
#        'VY_VELOCITY__GSE_km/s', 'VZ_VELOCITY__GSE_km/s', 'PROTON_DENSITY_n/cc',
#        'FLOW_PRESSURE_nPa', 'ELECTRIC_FIELD_mV/m', 'PLASMA_BETA_',
#        'ALFVEN_MACH_NO._', 'AU-INDEX_nT_y', 'SYM/D_INDEX_nT', 'ASY/D_INDEX_nT',
#        'ASY/H_INDEX_nT', 'RMSDEV_MAG_AVG_B_nT'],
#       dtype='object')

# %%
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 21s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 110/5000
# 5098/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00110: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 20s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 111/5000
# 5106/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00111: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 21s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 112/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00112: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 25s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 113/5000
# 5108/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00113: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 33s 7ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 114/5000
# 5102/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00114: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 115/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921 ETA: 0s - loss: 0.061
# Epoch 00115: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 116/5000
# 5101/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00116: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 117/5000
# 5106/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00117: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 118/5000
# 5102/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00118: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 119/5000
# 5110/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00119: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 120/5000
# 5110/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00120: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 121/5000
# 5104/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00121: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 122/5000
# 5106/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00122: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 123/5000
# 5102/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00123: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 124/5000
# 5108/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00124: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 125/5000
# 5099/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00125: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 22s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 126/5000
# 5101/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00126: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 127/5000
# 5107/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00127: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 128/5000
# 5103/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00128: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 129/5000
# 5101/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00129: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 130/5000
# 5108/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00130: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 131/5000
# 5111/5111 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00131: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 25s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 132/5000
# 5101/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00132: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 22s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 133/5000
# 5108/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00133: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 22s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 134/5000
# 5101/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00134: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 135/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00135: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 136/5000
# 5102/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921 ETA: 0s -
# Epoch 00136: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 137/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00137: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 22s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 138/5000
# 5099/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921 ETA: 0s - loss: 0.0610 - accuracy: 0.19
# Epoch 00138: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 139/5000
# 5111/5111 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00139: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 140/5000
# 5103/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00140: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 141/5000
# 5103/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00141: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 142/5000
# 5105/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00142: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 22s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 143/5000
# 5101/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00143: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 144/5000
# 5103/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00144: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 28s 6ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 145/5000
# 5099/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00145: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 22s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 146/5000
# 5110/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00146: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 22s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 147/5000
# 5105/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00147: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 25s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 148/5000
# 5106/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00148: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 25s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 149/5000
# 5110/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00149: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 150/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921 ETA: 0s - l
# Epoch 00150: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 151/5000
# 5108/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00151: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 152/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00152: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 153/5000
# 5108/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00153: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 29s 6ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 154/5000
# 5108/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00154: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 29s 6ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 155/5000
# 5110/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00155: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 26s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 156/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00156: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 157/5000
# 5110/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00157: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 27s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 158/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921 ETA: 0s - loss: 0.0
# Epoch 00158: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 27s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 159/5000
# 5106/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00159: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 29s 6ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 160/5000
# 5103/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00160: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 26s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 161/5000
# 5108/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00161: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 27s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 162/5000
# 5106/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00162: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 163/5000
# 5103/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00163: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 25s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 164/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00164: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 165/5000
# 5111/5111 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00165: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 166/5000
# 5107/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00166: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 167/5000
# 5100/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00167: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 22s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 168/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00168: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 169/5000
# 5104/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00169: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 170/5000
# 5102/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00170: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 171/5000
# 5104/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00171: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 22s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 172/5000
# 5106/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00172: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 173/5000
# 5107/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00173: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 25s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 174/5000
# 5103/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00174: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 175/5000
# 5107/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00175: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 176/5000
# 5106/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00176: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 177/5000
# 5108/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921 ETA: 0s - los - ETA: 0s - loss: 0.0610 - accuracy:
# Epoch 00177: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 178/5000
# 5103/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00178: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 179/5000
# 5099/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00179: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 25s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 180/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00180: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 181/5000
# 5109/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00181: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 182/5000
# 5108/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00182: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 183/5000
# 5101/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00183: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 184/5000
# 5104/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00184: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 22s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 185/5000
# 5110/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00185: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 23s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 186/5000
# 5106/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00186: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 24s 5ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 187/5000
# 5106/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00187: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 22s 4ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 188/5000
# 5110/5111 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.1921
# Epoch 00188: saving model to training_1\cp.ckpt
# 5111/5111 [==============================] - 28s 6ms/step - loss: 0.0610 - accuracy: 0.1921 - val_loss: 0.0540 - val_accuracy: 0.0992
# Epoch 189/5000
# 1730/5111 [=========>....................] - ETA: 18s - loss: 0.0610 - accuracy: 0.1924
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-231-e84f17956d7b> in <module>
#      17                     shuffle=True,
#      18                     callbacks=[cp_callback,
# ---> 19                                tensorboard_callback])
#      20
#      21 # Pass callback to training
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
# history = model.fit(x=X_train, y=y_train, batch_size=112, epochs=5, verbose=1, validation_data=(X_valid, y_valid), shuffle=True, callbacks=[tensorboard_callback])

# %%
os.listdir(checkpoint_dir)
# Out:
# ['checkpoint', 'cp.ckpt.data-00000-of-00001', 'cp.ckpt.index']

# %%
# Create a basic model instance
model = create_model()

# Evaluate the model
loss, acc = model.evaluate(X_valid, y_valid, verbose=2)
print("Untrained model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 3130/3130 - 2s - loss: 8.0688 - accuracy: 0.0480
# Untrained model, accuracy:  4.80%

# %%
# Loads the weights
model.load_weights(checkpoint_path)

# Re-evaluate the model
loss, acc = model.evaluate(X_valid, y_valid, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 3130/3130 - 2s - loss: 38.0494 - accuracy: 0.0407
# Restored model, accuracy:  4.07%

# %%
y_pred = model.predict(X_test)

# %%
test_array = np.array(y_test)

# %%
# y_test

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, y_pred)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
#regression line
y_test, y_predicted = y_test.reshape(-1,1), y_predicted.reshape(-1,1)
ax.plot(y_test, LinearRegression().fit(y_test, y_predicted).predict(y_test))
ax.set_title('R2: ' + str(r2_score(y_test, y_predicted)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-0c8e4cc52c70> in <module>
#       5 ax.set_ylabel('Predicted')
#       6 #regression line
# ----> 7 y_test, y_predicted = y_test.reshape(-1,1), y_predicted.reshape(-1,1)
#       8 ax.plot(y_test, LinearRegression().fit(y_test, y_predicted).predict(y_test))
#       9 ax.set_title('R2: ' + str(r2_score(y_test, y_predicted)))
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
y_pred
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
from sklearn.metrics import r2_score
# y_test_rescaled =  Target_scaler.inverse_transform(y_test_scaled)
score = r2_score(y_test, y_pred)
print('R-squared score for the test set:', round(score,4))
# Out:
# R-squared score for the test set: -63.3665

# %%
test_array = np.array(y_test)

# %%
y_actual = pd.DataFrame(test_array, columns=['Actual GIC'])

y_hat = pd.DataFrame(y_pred, columns=['Predicted GIC'])

# %%
plt.figure(figsize=(11, 6))
plt.plot(y_actual, linestyle='solid', color='r')
plt.plot(y_hat, linestyle='dashed', color='b')
# plt.plot(y_actual, linestyle='solid', color='r')


plt.legend(['Actual','Predicted'], loc='best', prop={'size': 14})
plt.title('db_diff', weight='bold', fontsize=16)
plt.ylabel('AMPs', weight='bold', fontsize=14)
plt.xlabel('Time [M] [Jan - Dec 2018]', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=45)
plt.yticks(weight='bold', fontsize=12)
plt.grid(color = 'y', linewidth='0.5')
plt.show()

# %% [markdown]
# ## ---------- Saving points

# %%
# logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
# tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
# logdir

# %%
# %tensorboard --logdir='C:\Users\cgree\Documents\logs\logs\20210816-141500'

# %%
# # Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# import tensorflow as tf
# import datetime, os

# %%
# os.chdir(r'C:\Users\cgree\Documents\logs')

# %%
# %tensorboard dev upload --logdir \
#     'runs'

# %%
# !rm -rf ./logs/

# %%
# %tensorboard --port=600 --logdir \
#     'runs'

# %% [markdown]
# ### Absolutly works
# (CleanTF) C:\Users\cgree\Documents\logs\logs\20210816-141500>tensorboard --port=9007 --logdir=train
#
# (CleanTF) C:\Users\cgree\Documents\logs\logs>tensorboard --port=9007 --logdir=20210816-141500

# %%
# history = model.fit(x=X_train, y=y_train, batch_size=112, epochs=5, verbose=1, validation_data=(X_valid, y_valid), shuffle=True, callbacks=[tensorboard_callback])

# %% [markdown]
# # Plot GIC and db_diff

# %%
y_pred = model.predict(X_test)

# %%
# y_pred_rescaled = Target_scaler.inverse_transform(y_pred)

# %%
from sklearn.metrics import r2_score
# y_test_rescaled =  Target_scaler.inverse_transform(y_test_scaled)
score = r2_score(y_test, y_pred)
print('R-squared score for the test set:', round(score,4))
# Out:
# R-squared score for the test set: -63.3665

# %%
test_array = np.array(y_test)

# %%
y_actual = pd.DataFrame(test_array, columns=['Actual GIC'])

y_hat = pd.DataFrame(y_pred, columns=['Predicted GIC'])

# %%
plt.figure(figsize=(11, 6))
plt.plot(y_actual, linestyle='solid', color='r')
plt.plot(y_hat, linestyle='dashed', color='b')
# plt.plot(y_actual, linestyle='solid', color='r')


plt.legend(['Actual','Predicted'], loc='best', prop={'size': 14})
plt.title('db_diff', weight='bold', fontsize=16)
plt.ylabel('AMPs [Scaled 0-1]', weight='bold', fontsize=14)
plt.xlabel('Time [M].', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=45)
plt.yticks(weight='bold', fontsize=12)
plt.grid(color = 'y', linewidth='0.5')
plt.show()

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['loss'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#Unknown fit - Validation error low, training error 'high'

# %%
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()

# %%
df.db_diff.plot()
# Out:
# <AxesSubplot:xlabel='Date_UTC'>

# %%
from scipy.stats import norm

# %%
#histogram and normal probability plot
sns.distplot(df['db_diff'], fit=norm);
fig = plt.figure()
res = stats.probplot(df1['db_diff'], plot=plt)
# Out:
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-54e9fc43177e> in <module>
#       2 sns.distplot(df['db_diff'], fit=norm);
#       3 fig = plt.figure()
# ----> 4 res = stats.probplot(df1['db_diff'], plot=plt)
#
# NameError: name 'stats' is not defined

# %% [markdown]
# ###### Something odd here let me go thought the

# %%
# from scipy import stats
# dfx = dfx[(np.abs(stats.zscore(dfx)) < 3).all(axis=1)] #3 standard deviations from mean

# # df.index = df['Datetime']
# # del df['Datetime']
# # df

# %%
dot_img_file = 'X:\\data_dumps\\tmp\\model_1.png'
plot_model(model, to_file=dot_img_file, show_shapes=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
# !pip install pydot
# Out:
# Requirement already satisfied: pydot in f:\astra\conda2\envs\cleantf\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in f:\astra\conda2\envs\cleantf\lib\site-packages (from pydot) (2.4.7)

# %%
import seaborn as sns

# %%
correlation_matrix = df.corr()
fig = plt.figure(figsize=(12,9))
sns.heatmap(correlation_matrix,vmax=0.8,square = True)
# plt.show()
# Out:
# <AxesSubplot:>

# %%
correlation_matrix
# Out:
#                          db_diff  DAILY_F10.7_  3-H_KP*10_  BY__GSM_nT  \
# db_diff                 1.000000     -0.212832    0.313494    0.020905
# DAILY_F10.7_           -0.212832      1.000000   -0.487678    0.006133
# 3-H_KP*10_              0.313494     -0.487678    1.000000    0.012644
# BY__GSM_nT              0.020905      0.006133    0.012644    1.000000
# BZ__GSM_nT             -0.114565      0.211851   -0.289097    0.006335
# RMS_SD_B_SCALAR_nT      0.104973      0.021955    0.062637    0.002328
# RMS_SD_FIELD_VECTOR_nT  0.112460     -0.055139    0.109014    0.005297
# VY_VELOCITY__GSE_km/s   0.062616     -0.105384    0.072011    0.003403
# VZ_VELOCITY__GSE_km/s   0.007217     -0.018558    0.014314   -0.010321
# PROTON_DENSITY_n/cc     0.085012      0.220539    0.040776    0.007834
# FLOW_PRESSURE_nPa       0.227670      0.023877    0.200316    0.012927
# ELECTRIC_FIELD_mV/m     0.097243     -0.172380    0.236620   -0.003297
# PLASMA_BETA_           -0.018466      0.097545   -0.047913    0.003048
# ALFVEN_MACH_NO._       -0.025155      0.156676   -0.082500    0.003329
# AU-INDEX_nT_x           0.283856     -0.377408    0.647130   -0.017383
# SYM/D_INDEX_nT         -0.046005      0.165106   -0.094218    0.024030
# ASY/D_INDEX_nT          0.306265     -0.416332    0.504367    0.023087
# ASY/H_INDEX_nT          0.342536     -0.514542    0.591308    0.050343
# RMSDEV_MAG_AVG_B_nT     0.241715      0.017053    0.193231    0.006612
# states                  0.385992     -0.320970    0.462668    0.002465
#
#                         BZ__GSM_nT  RMS_SD_B_SCALAR_nT  \
# db_diff                  -0.114565            0.104973
# DAILY_F10.7_              0.211851            0.021955
# 3-H_KP*10_               -0.289097            0.062637
# BY__GSM_nT                0.006335            0.002328
# BZ__GSM_nT                1.000000           -0.006518
# RMS_SD_B_SCALAR_nT       -0.006518            1.000000
# RMS_SD_FIELD_VECTOR_nT   -0.005280            0.554742
# VY_VELOCITY__GSE_km/s     0.002420            0.064181
# VZ_VELOCITY__GSE_km/s     0.014481           -0.011147
# PROTON_DENSITY_n/cc       0.005457            0.166767
# FLOW_PRESSURE_nPa        -0.001892            0.212140
# ELECTRIC_FIELD_mV/m      -0.703105            0.004980
# PLASMA_BETA_             -0.001284            0.035414
# ALFVEN_MACH_NO._         -0.004626            0.063840
# AU-INDEX_nT_x            -0.288290            0.078517
# SYM/D_INDEX_nT            0.038236            0.014188
# ASY/D_INDEX_nT           -0.197943            0.069686
# ASY/H_INDEX_nT           -0.248597            0.082667
# RMSDEV_MAG_AVG_B_nT      -0.015011            0.305872
# states                   -0.212027            0.055791
#
#                         RMS_SD_FIELD_VECTOR_nT  VY_VELOCITY__GSE_km/s  \
# db_diff                               0.112460               0.062616
# DAILY_F10.7_                         -0.055139              -0.105384
# 3-H_KP*10_                            0.109014               0.072011
# BY__GSM_nT                            0.005297               0.003403
# BZ__GSM_nT                           -0.005280               0.002420
# RMS_SD_B_SCALAR_nT                    0.554742               0.064181
# RMS_SD_FIELD_VECTOR_nT                1.000000               0.104643
# VY_VELOCITY__GSE_km/s                 0.104643               1.000000
# VZ_VELOCITY__GSE_km/s                -0.013416              -0.022482
# PROTON_DENSITY_n/cc                   0.085375              -0.088334
# FLOW_PRESSURE_nPa                     0.177313               0.041725
# ELECTRIC_FIELD_mV/m                   0.004156              -0.003003
# PLASMA_BETA_                         -0.025161              -0.005865
# ALFVEN_MACH_NO._                     -0.040579               0.002980
# AU-INDEX_nT_x                         0.115776               0.062351
# SYM/D_INDEX_nT                        0.003437              -0.020839
# ASY/D_INDEX_nT                        0.106041               0.040385
# ASY/H_INDEX_nT                        0.125912               0.055730
# RMSDEV_MAG_AVG_B_nT                   0.203696               0.068088
# states                                0.102467               0.080151
#
#                         VZ_VELOCITY__GSE_km/s  PROTON_DENSITY_n/cc  \
# db_diff                              0.007217             0.085012
# DAILY_F10.7_                        -0.018558             0.220539
# 3-H_KP*10_                           0.014314             0.040776
# BY__GSM_nT                          -0.010321             0.007834
# BZ__GSM_nT                           0.014481             0.005457
# RMS_SD_B_SCALAR_nT                  -0.011147             0.166767
# RMS_SD_FIELD_VECTOR_nT              -0.013416             0.085375
# VY_VELOCITY__GSE_km/s               -0.022482            -0.088334
# VZ_VELOCITY__GSE_km/s                1.000000             0.002511
# PROTON_DENSITY_n/cc                  0.002511             1.000000
# FLOW_PRESSURE_nPa                    0.000599             0.582934
# ELECTRIC_FIELD_mV/m                 -0.017692            -0.006652
# PLASMA_BETA_                         0.001110             0.141811
# ALFVEN_MACH_NO._                    -0.001093             0.194466
# AU-INDEX_nT_x                        0.013765             0.080924
# SYM/D_INDEX_nT                      -0.010642             0.051078
# ASY/D_INDEX_nT                       0.001523             0.071621
# ASY/H_INDEX_nT                       0.011712             0.078084
# RMSDEV_MAG_AVG_B_nT                 -0.007400             0.312884
# states                               0.002513             0.003226
#
#                         FLOW_PRESSURE_nPa  ELECTRIC_FIELD_mV/m  PLASMA_BETA_  \
# db_diff                          0.227670             0.097243     -0.018466
# DAILY_F10.7_                     0.023877            -0.172380      0.097545
# 3-H_KP*10_                       0.200316             0.236620     -0.047913
# BY__GSM_nT                       0.012927            -0.003297      0.003048
# BZ__GSM_nT                      -0.001892            -0.703105     -0.001284
# RMS_SD_B_SCALAR_nT               0.212140             0.004980      0.035414
# RMS_SD_FIELD_VECTOR_nT           0.177313             0.004156     -0.025161
# VY_VELOCITY__GSE_km/s            0.041725            -0.003003     -0.005865
# VZ_VELOCITY__GSE_km/s            0.000599            -0.017692      0.001110
# PROTON_DENSITY_n/cc              0.582934            -0.006652      0.141811
# FLOW_PRESSURE_nPa                1.000000             0.003573      0.067633
# ELECTRIC_FIELD_mV/m              0.003573             1.000000     -0.000031
# PLASMA_BETA_                     0.067633            -0.000031      1.000000
# ALFVEN_MACH_NO._                 0.126629             0.003718      0.548878
# AU-INDEX_nT_x                    0.223124             0.232419     -0.044126
# SYM/D_INDEX_nT                   0.013329            -0.033348      0.014597
# ASY/D_INDEX_nT                   0.218138             0.165521     -0.047128
# ASY/H_INDEX_nT                   0.242607             0.206835     -0.054314
# RMSDEV_MAG_AVG_B_nT              0.414955             0.017168      0.028571
# states                           0.149176             0.164307     -0.078217
#
#                         ALFVEN_MACH_NO._  AU-INDEX_nT_x  SYM/D_INDEX_nT  \
# db_diff                        -0.025155       0.283856       -0.046005
# DAILY_F10.7_                    0.156676      -0.377408        0.165106
# 3-H_KP*10_                     -0.082500       0.647130       -0.094218
# BY__GSM_nT                      0.003329      -0.017383        0.024030
# BZ__GSM_nT                     -0.004626      -0.288290        0.038236
# RMS_SD_B_SCALAR_nT              0.063840       0.078517        0.014188
# RMS_SD_FIELD_VECTOR_nT         -0.040579       0.115776        0.003437
# VY_VELOCITY__GSE_km/s           0.002980       0.062351       -0.020839
# VZ_VELOCITY__GSE_km/s          -0.001093       0.013765       -0.010642
# PROTON_DENSITY_n/cc             0.194466       0.080924        0.051078
# FLOW_PRESSURE_nPa               0.126629       0.223124        0.013329
# ELECTRIC_FIELD_mV/m             0.003718       0.232419       -0.033348
# PLASMA_BETA_                    0.548878      -0.044126        0.014597
# ALFVEN_MACH_NO._                1.000000      -0.080683        0.021565
# AU-INDEX_nT_x                  -0.080683       1.000000       -0.044155
# SYM/D_INDEX_nT                  0.021565      -0.044155        1.000000
# ASY/D_INDEX_nT                 -0.086597       0.419410       -0.091957
# ASY/H_INDEX_nT                 -0.106418       0.493626       -0.061787
# RMSDEV_MAG_AVG_B_nT             0.029380       0.219916        0.008735
# states                         -0.113312       0.440565       -0.048564
#
#                         ASY/D_INDEX_nT  ASY/H_INDEX_nT  RMSDEV_MAG_AVG_B_nT  \
# db_diff                       0.306265        0.342536             0.241715
# DAILY_F10.7_                 -0.416332       -0.514542             0.017053
# 3-H_KP*10_                    0.504367        0.591308             0.193231
# BY__GSM_nT                    0.023087        0.050343             0.006612
# BZ__GSM_nT                   -0.197943       -0.248597            -0.015011
# RMS_SD_B_SCALAR_nT            0.069686        0.082667             0.305872
# RMS_SD_FIELD_VECTOR_nT        0.106041        0.125912             0.203696
# VY_VELOCITY__GSE_km/s         0.040385        0.055730             0.068088
# VZ_VELOCITY__GSE_km/s         0.001523        0.011712            -0.007400
# PROTON_DENSITY_n/cc           0.071621        0.078084             0.312884
# FLOW_PRESSURE_nPa             0.218138        0.242607             0.414955
# ELECTRIC_FIELD_mV/m           0.165521        0.206835             0.017168
# PLASMA_BETA_                 -0.047128       -0.054314             0.028571
# ALFVEN_MACH_NO._             -0.086597       -0.106418             0.029380
# AU-INDEX_nT_x                 0.419410        0.493626             0.219916
# SYM/D_INDEX_nT               -0.091957       -0.061787             0.008735
# ASY/D_INDEX_nT                1.000000        0.627087             0.206924
# ASY/H_INDEX_nT                0.627087        1.000000             0.243302
# RMSDEV_MAG_AVG_B_nT           0.206924        0.243302             1.000000
# states                        0.297147        0.348372             0.155260
#
#                           states
# db_diff                 0.385992
# DAILY_F10.7_           -0.320970
# 3-H_KP*10_              0.462668
# BY__GSM_nT              0.002465
# BZ__GSM_nT             -0.212027
# RMS_SD_B_SCALAR_nT      0.055791
# RMS_SD_FIELD_VECTOR_nT  0.102467
# VY_VELOCITY__GSE_km/s   0.080151
# VZ_VELOCITY__GSE_km/s   0.002513
# PROTON_DENSITY_n/cc     0.003226
# FLOW_PRESSURE_nPa       0.149176
# ELECTRIC_FIELD_mV/m     0.164307
# PLASMA_BETA_           -0.078217
# ALFVEN_MACH_NO._       -0.113312
# AU-INDEX_nT_x           0.440565
# SYM/D_INDEX_nT         -0.048564
# ASY/D_INDEX_nT          0.297147
# ASY/H_INDEX_nT          0.348372
# RMSDEV_MAG_AVG_B_nT     0.155260
# states                  1.000000

# %%
# GSM similar to the GSE due to time delay.

# %%
#target correlation matrix
k = 10 #number of variables for heatmap`ax
cols = correlation_matrix.nlargest(k, 'db_diff')['db_diff'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
# !pip install statsmodels

# %% [markdown]
# ### variables’ effect on the dependent variable

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
#  6958220        0.059278        0.033058             0.010101       0
#  6958221        0.059278        0.033058             0.010101       1
#  6958222        0.059278        0.035813             0.010101       1
#
#  [6958223 rows x 19 columns])

# %% [markdown]
# ##### The F-statistic is blowing up 122300% , this should tell us the accuracy of the null hypthesis
# ###### - reject the null hypothesis with 95 percent confidence that the variance between the values isn't due to random chance
#
# ##### some of the variables are showing low signficiance (Electric_field,1AU_IP_FLOW_LAT_Deg, 1AU_IP_BX__GSE_nT, RMSDEV_TEMP_Deg_K )

# %%
#### Scaling may be an issue due to log scale.

# %%
model = sm.OLS( y_train,X_train)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                db_diff   R-squared (uncentered):                   0.486
# Model:                            OLS   Adj. R-squared (uncentered):              0.486
# Method:                 Least Squares   F-statistic:                          3.466e+05
# Date:                Wed, 11 Aug 2021   Prob (F-statistic):                        0.00
# Time:                        14:34:04   Log-Likelihood:                      2.2201e+07
# No. Observations:             6958223   AIC:                                 -4.440e+07
# Df Residuals:                 6958204   BIC:                                 -4.440e+07
# Df Model:                          19
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# DAILY_F10.7_              -0.0022   8.93e-05    -24.854      0.000      -0.002      -0.002
# 3-H_KP*10_                 0.0032   6.67e-05     48.559      0.000       0.003       0.003
# BY__GSM_nT                 0.0018    7.2e-05     24.994      0.000       0.002       0.002
# BZ__GSM_nT                 0.0021   9.86e-05     21.639      0.000       0.002       0.002
# RMS_SD_B_SCALAR_nT         0.0131      0.000     41.010      0.000       0.012       0.014
# RMS_SD_FIELD_VECTOR_nT     0.0030      0.000     22.469      0.000       0.003       0.003
# VY_VELOCITY__GSE_km/s      0.0021   7.97e-05     26.611      0.000       0.002       0.002
# VZ_VELOCITY__GSE_km/s      0.0010   6.92e-05     13.803      0.000       0.001       0.001
# PROTON_DENSITY_n/cc       -0.0049   8.43e-05    -58.124      0.000      -0.005      -0.005
# FLOW_PRESSURE_nPa          0.0432      0.000    213.407      0.000       0.043       0.044
# ELECTRIC_FIELD_mV/m        0.0007      0.000      5.453      0.000       0.000       0.001
# PLASMA_BETA_              -0.0003      0.001     -0.449      0.654      -0.001       0.001
# ALFVEN_MACH_NO._           0.0159      0.000     49.842      0.000       0.015       0.016
# AU-INDEX_nT_x             -0.0002      0.000     -1.413      0.158      -0.001    8.85e-05
# SYM/D_INDEX_nT            -0.0062      0.000    -46.759      0.000      -0.007      -0.006
# ASY/D_INDEX_nT             0.0308      0.000    194.185      0.000       0.030       0.031
# ASY/H_INDEX_nT             0.0378      0.000    236.277      0.000       0.037       0.038
# RMSDEV_MAG_AVG_B_nT        0.0290      0.000    270.980      0.000       0.029       0.029
# states                     0.0062   9.12e-06    678.660      0.000       0.006       0.006
# ==============================================================================
# Omnibus:                  9347112.197   Durbin-Watson:                   1.449
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      14159793335.992
# Skew:                           6.973   Prob(JB):                         0.00
# Kurtosis:                     223.556   Cond. No.                         241.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
norm_x = X_test.values
for i, name in enumerate(X_test):
    if name == "const":
        continue
    norm_x[:,i] = X_test[name]/np.linalg.norm(X_test[name])
norm_xtx = np.dot(norm_x.T,norm_x)

# %%
eigs = np.linalg.eigvals(norm_xtx)
condition_number = np.sqrt(eigs.max() / eigs.min())
print(condition_number)
# Out:
# 308.9186005887479

# %%
# results = sm.OLS(y_test.iloc[:14], X_test.iloc[:14]).fit()
# print("Percentage change %4.2f%%\n"*7 % tuple([i for i in (results.params - results.params)/results.params*100]))

# %%
print('Parameters: ', results.params)
print('R2: ', results.rsquared)
# Out:
# Parameters:  NO._IMF_AVG_                         -0.003261
# NO._IP_PLASMA_AVG_                    0.001237
# BX__GSE_nT                           -0.001283
# BY__GSE_nT                           -0.001025
# BZ__GSE_nT                           -0.002118
# BY__GSM_nT                            0.000387
# BZ__GSM_nT                            0.006216
# RMS_SD_B_SCALAR_nT                    0.013343
# RMS_SD_FIELD_VECTOR_nT                0.000589
# VY_VELOCITY__GSE_km/s                 0.002158
# VZ_VELOCITY__GSE_km/s                 0.000533
# PROTON_DENSITY_n/cc                  -0.002967
# TEMPERATURE_K                        -0.003153
# NA/NP_RATIO_                          0.000284
# FLOW_PRESSURE_nPa                     0.020508
# ELECTRIC_FIELD_mV/m                  -0.000115
# PLASMA_BETA_                         -0.007762
# ALFVEN_MACH_NO._                      0.015739
# Y_(S/C)__GSE_Re                      -0.000437
# Z_(S/C)__GSE_Re                      -0.000188
# Y_(BSN)__GSE_Re                       0.004252
# Z_(BSN)__GSE_Re                      -0.001289
# 1-M_AE_nT                            -0.013630
# 1-M_AL-INDEX_nT                      -0.019231
# AU-INDEX_nT_x                         0.008598
# SYM/D_INDEX_nT                        0.001152
# ASY/D_INDEX_nT                        0.017330
# ASY/H_INDEX_nT                        0.017561
# 1AU_IP_LAT/THETA_AVG_B_Deg            0.001368
# 1AU_IP_LONG/PHI_AVG_B_Deg             0.000063
# 1AU_IP_BX__GSE_nT                    -0.000105
# 1AU_IP_BY__GSM_nT                     0.001464
# RMSDEV_MAG_AVG_B_nT                   0.001952
# RMSDEV_BX_GSE_nT                     -0.005575
# RMSDEV_BY_GSE_nT                      0.008001
# RMSDEV_BZ_GSE_nT                      0.002529
# 1AU_IP_PLASMA_TEMP_Deg_K             -0.000147
# 1AU_IP_N_(ION)_Per_cc                -0.006615
# 1AU_IP_FLOW_LONG_Deg                  0.002505
# 1AU_IP_FLOW_LAT_Deg                  -0.000096
# 1AU_IP_ALPHA/PROTON_                  0.003536
# RMSDEV_TEMP_Deg_K                     0.000614
# RMSDEV_N(ION)_Per_cc                  0.035703
# RMSDEV_SPEED_Km/s                     0.011723
# RMSDEV_FLOW_LONG_Deg                 -0.011437
# RMSDEV_FLOW_LAT_Deg                  -0.003338
# RMSDEV_A/P_RATIO_                     0.001077
# 1AU_IP_ELECTRIC_FIELD_mV/m            0.005884
# 1AU_IP_PLASMA_BETA_                   0.026168
# 1AU_PROTONS>10_MEV_1/(SQcm-ster-s)    0.042001
# 1AU_PROTONS>30_MEV_1/(SQcm-ster-s)   -0.026459
# 1AU_PROTONS>60_MEV_1/(SQcm-ster-s)    0.023853
# DAILY_F10.7_                          0.013102
# 3-H_KP*10_                           -0.002104
# 1-H_DST_nT                            0.073663
# 1-H_AE_nT                             0.001326
# 3-H_AP_nT                            -0.007049
# 1-H_AL-INDEX_nT                      -0.007482
# 1-H_PC(N)-INDEX_                     -0.004904
# states                                0.006428
# dtype: float64
# R2:  0.5133813109353125

# %%
print('Parameters: ', results.params)
print('Standard errors: ', results.bse)
print('Predicted values: ', results.predict())
# Out:
# Parameters:  NO._IMF_AVG_                         -0.003261
# NO._IP_PLASMA_AVG_                    0.001237
# BX__GSE_nT                           -0.001283
# BY__GSE_nT                           -0.001025
# BZ__GSE_nT                           -0.002118
# BY__GSM_nT                            0.000387
# BZ__GSM_nT                            0.006216
# RMS_SD_B_SCALAR_nT                    0.013343
# RMS_SD_FIELD_VECTOR_nT                0.000589
# VY_VELOCITY__GSE_km/s                 0.002158
# VZ_VELOCITY__GSE_km/s                 0.000533
# PROTON_DENSITY_n/cc                  -0.002967
# TEMPERATURE_K                        -0.003153
# NA/NP_RATIO_                          0.000284
# FLOW_PRESSURE_nPa                     0.020508
# ELECTRIC_FIELD_mV/m                  -0.000115
# PLASMA_BETA_                         -0.007762
# ALFVEN_MACH_NO._                      0.015739
# Y_(S/C)__GSE_Re                      -0.000437
# Z_(S/C)__GSE_Re                      -0.000188
# Y_(BSN)__GSE_Re                       0.004252
# Z_(BSN)__GSE_Re                      -0.001289
# 1-M_AE_nT                            -0.013630
# 1-M_AL-INDEX_nT                      -0.019231
# AU-INDEX_nT_x                         0.008598
# SYM/D_INDEX_nT                        0.001152
# ASY/D_INDEX_nT                        0.017330
# ASY/H_INDEX_nT                        0.017561
# 1AU_IP_LAT/THETA_AVG_B_Deg            0.001368
# 1AU_IP_LONG/PHI_AVG_B_Deg             0.000063
# 1AU_IP_BX__GSE_nT                    -0.000105
# 1AU_IP_BY__GSM_nT                     0.001464
# RMSDEV_MAG_AVG_B_nT                   0.001952
# RMSDEV_BX_GSE_nT                     -0.005575
# RMSDEV_BY_GSE_nT                      0.008001
# RMSDEV_BZ_GSE_nT                      0.002529
# 1AU_IP_PLASMA_TEMP_Deg_K             -0.000147
# 1AU_IP_N_(ION)_Per_cc                -0.006615
# 1AU_IP_FLOW_LONG_Deg                  0.002505
# 1AU_IP_FLOW_LAT_Deg                  -0.000096
# 1AU_IP_ALPHA/PROTON_                  0.003536
# RMSDEV_TEMP_Deg_K                     0.000614
# RMSDEV_N(ION)_Per_cc                  0.035703
# RMSDEV_SPEED_Km/s                     0.011723
# RMSDEV_FLOW_LONG_Deg                 -0.011437
# RMSDEV_FLOW_LAT_Deg                  -0.003338
# RMSDEV_A/P_RATIO_                     0.001077
# 1AU_IP_ELECTRIC_FIELD_mV/m            0.005884
# 1AU_IP_PLASMA_BETA_                   0.026168
# 1AU_PROTONS>10_MEV_1/(SQcm-ster-s)    0.042001
# 1AU_PROTONS>30_MEV_1/(SQcm-ster-s)   -0.026459
# 1AU_PROTONS>60_MEV_1/(SQcm-ster-s)    0.023853
# DAILY_F10.7_                          0.013102
# 3-H_KP*10_                           -0.002104
# 1-H_DST_nT                            0.073663
# 1-H_AE_nT                             0.001326
# 3-H_AP_nT                            -0.007049
# 1-H_AL-INDEX_nT                      -0.007482
# 1-H_PC(N)-INDEX_                     -0.004904
# states                                0.006428
# dtype: float64
# Standard errors:  NO._IMF_AVG_                          0.000429
# NO._IP_PLASMA_AVG_                    0.000255
# BX__GSE_nT                            0.000119
# BY__GSE_nT                            0.000152
# BZ__GSE_nT                            0.000183
# BY__GSM_nT                            0.000153
# BZ__GSM_nT                            0.000183
# RMS_SD_B_SCALAR_nT                    0.000313
# RMS_SD_FIELD_VECTOR_nT                0.000137
# VY_VELOCITY__GSE_km/s                 0.000108
# VZ_VELOCITY__GSE_km/s                 0.000092
# PROTON_DENSITY_n/cc                   0.000094
# TEMPERATURE_K                         0.000452
# NA/NP_RATIO_                          0.000103
# FLOW_PRESSURE_nPa                     0.000209
# ELECTRIC_FIELD_mV/m                   0.000175
# PLASMA_BETA_                          0.000587
# ALFVEN_MACH_NO._                      0.000333
# Y_(S/C)__GSE_Re                       0.000014
# Z_(S/C)__GSE_Re                       0.000012
# Y_(BSN)__GSE_Re                       0.000160
# Z_(BSN)__GSE_Re                       0.000097
# 1-M_AE_nT                             0.000152
# 1-M_AL-INDEX_nT                       0.000151
# AU-INDEX_nT_x                         0.000207
# SYM/D_INDEX_nT                        0.000137
# ASY/D_INDEX_nT                        0.000158
# ASY/H_INDEX_nT                        0.000165
# 1AU_IP_LAT/THETA_AVG_B_Deg            0.000036
# 1AU_IP_LONG/PHI_AVG_B_Deg             0.000018
# 1AU_IP_BX__GSE_nT                     0.000092
# 1AU_IP_BY__GSM_nT                     0.000122
# RMSDEV_MAG_AVG_B_nT                   0.000147
# RMSDEV_BX_GSE_nT                      0.000154
# RMSDEV_BY_GSE_nT                      0.000123
# RMSDEV_BZ_GSE_nT                      0.000122
# 1AU_IP_PLASMA_TEMP_Deg_K              0.000273
# 1AU_IP_N_(ION)_Per_cc                 0.000200
# 1AU_IP_FLOW_LONG_Deg                  0.000104
# 1AU_IP_FLOW_LAT_Deg                   0.000076
# 1AU_IP_ALPHA/PROTON_                  0.000145
# RMSDEV_TEMP_Deg_K                     0.000408
# RMSDEV_N(ION)_Per_cc                  0.000372
# RMSDEV_SPEED_Km/s                     0.000187
# RMSDEV_FLOW_LONG_Deg                  0.000257
# RMSDEV_FLOW_LAT_Deg                   0.000081
# RMSDEV_A/P_RATIO_                     0.000372
# 1AU_IP_ELECTRIC_FIELD_mV/m            0.000204
# 1AU_IP_PLASMA_BETA_                   0.000383
# 1AU_PROTONS>10_MEV_1/(SQcm-ster-s)    0.000835
# 1AU_PROTONS>30_MEV_1/(SQcm-ster-s)    0.001155
# 1AU_PROTONS>60_MEV_1/(SQcm-ster-s)    0.000857
# DAILY_F10.7_                          0.000102
# 3-H_KP*10_                            0.000100
# 1-H_DST_nT                            0.000142
# 1-H_AE_nT                             0.000105
# 3-H_AP_nT                             0.000122
# 1-H_AL-INDEX_nT                       0.000131
# 1-H_PC(N)-INDEX_                      0.000357
# states                                0.000010
# dtype: float64
# Predicted values:  [0.00560858 0.00561838 0.00560482 ... 0.00340981 0.00823326 0.00886832]

# %%
prstd, iv_l, iv_u = wls_prediction_std(results)

fig, ax = plt.subplots(figsize=(8,6))

ax.plot(X_test, y_test, 'o', label="data")
ax.plot(X_test, y_test, 'b-', label="True")
ax.plot(X_test, res.fittedvalues, 'r--.', label="OLS")
ax.plot(X_test, iv_u, 'r--')
ax.plot(X_test, iv_l, 'r--')
ax.legend(loc='best');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-12ffd5250ce7> in <module>
#       5 ax.plot(X_test, y_test, 'o', label="data")
#       6 ax.plot(X_test, y_test, 'b-', label="True")
# ----> 7 ax.plot(X_test, res.fittedvalues, 'r--.', label="OLS")
#       8 ax.plot(X_test, iv_u, 'r--')
#       9 ax.plot(X_test, iv_l, 'r--')
#
# NameError: name 'res' is not defined
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\backends\backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     160             try:
# --> 161                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     162             except OverflowError as err:
#
# OverflowError: In draw_path: Exceeded cell block limit
#
# The above exception was the direct cause of the following exception:
#
# OverflowError                             Traceback (most recent call last)
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2259                         orientation=orientation,
#    2260                         bbox_inches_restore=_bbox_inches_restore,
# -> 2261                         **kwargs)
#    2262             finally:
#    2263                 if bbox_inches and restore_bbox:
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     506             *metadata*, including the default 'Software' key.
#     507         """
# --> 508         FigureCanvasAgg.draw(self)
#     509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2779             self.patch.draw(renderer)
#    2780             mimage._draw_list_compositing_images(
# -> 2781                 renderer, self, artists, self.suppressComposite)
#    2782
#    2783             for sfig in self.subfigs:
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2919             renderer.stop_rasterizing()
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#    2923         renderer.close_group('axes')
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\lines.py in draw(self, renderer)
#     794
#     795                 gc.set_dashes(self._dashOffset, self._dashSeq)
# --> 796                 renderer.draw_path(gc, tpath, affine.frozen())
#     797                 gc.restore()
#     798
#
# F:\Astra\conda2\envs\CleanTF\lib\site-packages\matplotlib\backends\backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     162             except OverflowError as err:
#     163                 raise OverflowError("Exceeded cell block limit (set "
# --> 164                                     "'agg.path.chunksize' rcparam)") from err
#     165
#     166     def draw_path_collection(self, gc, master_transform, paths, all_transforms,
#
# OverflowError: Exceeded cell block limit (set 'agg.path.chunksize' rcparam)

# %%
DAILY_F10.7_                         
3-H_KP*10_     
BY__GSM_nT
BZ__GSM_nT
RMS_SD_B_SCALAR_nT
RMS_SD_FIELD_VECTOR_nT
VY_VELOCITY__GSE_km/s
VZ_VELOCITY__GSE_km/s
PROTON_DENSITY_n/cc
FLOW_PRESSURE_nPa
ELECTRIC_FIELD_mV/m
PLASMA_BETA_
ALFVEN_MACH_NO._
AU-INDEX_nT_x
SYM/D_INDEX_nT
ASY/D_INDEX_nT
ASY/H_INDEX_nT        
RMSDEV_MAG_AVG_B_nT
