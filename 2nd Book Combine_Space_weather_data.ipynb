# %%
import pandas as pd
import os

# %%
list_of_files = os.listdir('X:\data_dumps\Combined_Weakly')

# %%
 w = 'X:\data_dumps\Combined_Weakly'

# %%
df = pd.DataFrame()
df2 = pd.DataFrame()

# %%
for x in list_of_files:
    df = pd.DataFrame()
    df = pd.read_hdf(w + "\\" + x)
    df2 = df2.append(df)

# %%
compression_opts = dict(method='zip',
                        archive_name='weakly_2018.csv')  
df2.to_csv('weakly_2018.zip', index=False,
          compression=compression_opts)

# %%
df2 = pd.read_csv(r'weakly_2018.zip', compression='zip')

# %%
df2
# Out:
#                      Datetime   gic        Bz        By        Bx     clock  \
# 0         2018-01-01 00:00:00  0.17 -5.540700 -3.928933 -0.160000  3.758403
# 1         2018-01-01 00:00:01  0.17 -5.533348 -3.942693 -0.150167  3.760681
# 2         2018-01-01 00:00:02  0.16 -5.525997 -3.956453 -0.140333  3.762957
# 3         2018-01-01 00:00:03  0.19 -5.518645 -3.970213 -0.130500  3.765232
# 4         2018-01-01 00:00:04  0.15 -5.511293 -3.983973 -0.120667  3.767506
# ...                       ...   ...       ...       ...       ...       ...
# 30786169  2018-12-31 23:59:55  0.10  2.842267  2.100433 -3.306100  0.636423
# 30786170  2018-12-31 23:59:56  0.14  2.840353  2.101353 -3.307660  0.636955
# 30786171  2018-12-31 23:59:57  0.12  2.838440  2.102273 -3.309220  0.637486
# 30786172  2018-12-31 23:59:58  0.10  2.836527  2.103193 -3.310780  0.638018
# 30786173  2018-12-31 23:59:59  0.14  2.834613  2.104113 -3.312340  0.638550
#
# ...

# %%
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#                      Datetime   gic        Bz        By        Bx     clock  \
# 0         2018-01-01 00:00:00  0.17 -5.540700 -3.928933 -0.160000  3.758403
# 1         2018-01-01 00:00:01  0.17 -5.533348 -3.942693 -0.150167  3.760681
# 2         2018-01-01 00:00:02  0.16 -5.525997 -3.956453 -0.140333  3.762957
# 3         2018-01-01 00:00:03  0.19 -5.518645 -3.970213 -0.130500  3.765232
# 4         2018-01-01 00:00:04  0.15 -5.511293 -3.983973 -0.120667  3.767506
# ...                       ...   ...       ...       ...       ...       ...
# 30786169  2018-12-31 23:59:55  0.10  2.842267  2.100433 -3.306100  0.636423
# 30786170  2018-12-31 23:59:56  0.14  2.840353  2.101353 -3.307660  0.636955
# 30786171  2018-12-31 23:59:57  0.12  2.838440  2.102273 -3.309220  0.637486
# 30786172  2018-12-31 23:59:58  0.10  2.836527  2.103193 -3.310780  0.638018
# 30786173  2018-12-31 23:59:59  0.14  2.834613  2.104113 -3.312340  0.638550
#
# ...

# %%
dfw = pd.DataFrame()
dft = pd.DataFrame()

# %%
dfw=df2.copy()

# %%
dfw
# Out:
#                      Datetime   gic        Bz        By        Bx     clock  \
# 0         2018-01-01 00:00:00  0.17 -5.540700 -3.928933 -0.160000  3.758403
# 1         2018-01-01 00:00:01  0.17 -5.533348 -3.942693 -0.150167  3.760681
# 2         2018-01-01 00:00:02  0.16 -5.525997 -3.956453 -0.140333  3.762957
# 3         2018-01-01 00:00:03  0.19 -5.518645 -3.970213 -0.130500  3.765232
# 4         2018-01-01 00:00:04  0.15 -5.511293 -3.983973 -0.120667  3.767506
# ...                       ...   ...       ...       ...       ...       ...
# 30786169  2018-12-31 23:59:55  0.10  2.842267  2.100433 -3.306100  0.636423
# 30786170  2018-12-31 23:59:56  0.14  2.840353  2.101353 -3.307660  0.636955
# 30786171  2018-12-31 23:59:57  0.12  2.838440  2.102273 -3.309220  0.637486
# 30786172  2018-12-31 23:59:58  0.10  2.836527  2.103193 -3.310780  0.638018
# 30786173  2018-12-31 23:59:59  0.14  2.834613  2.104113 -3.312340  0.638550
#
# ...

# %%
 dfw['Datetime'] = dfw['Datetime'].astype('datetime64[ns]')

# %%
dfw
# Out:
#                     Datetime   gic        Bz        By        Bx     clock  \
# 0        2018-01-01 00:00:00  0.17 -5.540700 -3.928933 -0.160000  3.758403
# 1        2018-01-01 00:00:01  0.17 -5.533348 -3.942693 -0.150167  3.760681
# 2        2018-01-01 00:00:02  0.16 -5.525997 -3.956453 -0.140333  3.762957
# 3        2018-01-01 00:00:03  0.19 -5.518645 -3.970213 -0.130500  3.765232
# 4        2018-01-01 00:00:04  0.15 -5.511293 -3.983973 -0.120667  3.767506
# ...                      ...   ...       ...       ...       ...       ...
# 30786169 2018-12-31 23:59:55  0.10  2.842267  2.100433 -3.306100  0.636423
# 30786170 2018-12-31 23:59:56  0.14  2.840353  2.101353 -3.307660  0.636955
# 30786171 2018-12-31 23:59:57  0.12  2.838440  2.102273 -3.309220  0.637486
# 30786172 2018-12-31 23:59:58  0.10  2.836527  2.103193 -3.310780  0.638018
# 30786173 2018-12-31 23:59:59  0.14  2.834613  2.104113 -3.312340  0.638550
#
# ...

# %%
#dfw = dfw.set_index('Datetime')

# %%
dfw.head()
# Out:
#               Datetime   gic        Bz        By        Bx     clock  \
# 0  2018-01-01 00:00:00  0.17 -5.540700 -3.928933 -0.160000  3.758403
# 1  2018-01-01 00:00:01  0.17 -5.533348 -3.942693 -0.150167  3.760681
# 2  2018-01-01 00:00:02  0.16 -5.525997 -3.956453 -0.140333  3.762957
# 3  2018-01-01 00:00:03  0.19 -5.518645 -3.970213 -0.130500  3.765232
# 4  2018-01-01 00:00:04  0.15 -5.511293 -3.983973 -0.120667  3.767506
#
#          AE      SymH         Vsw        Dsw       Psw       newell
# 0  285.2500 -3.640000  371.070000  13.012667  3.584333  8408.696468
# 1  285.3405 -3.658667  371.077844  13.014269  3.584904  8402.231771
# 2  285.4310 -3.677333  371.085689  13.015871  3.585476  8395.785348
# 3  285.5215 -3.696000  371.093533  13.017473  3.586047  8389.357086
# 4  285.6120 -3.714667  371.101378  13.019076  3.586618  8382.947127

# %%
dfw['seconds'] = dfw['Datetime'].dt.second

# %%
dfw
# Out:
#                     Datetime   gic        Bz        By        Bx     clock  \
# 0        2018-01-01 00:00:00  0.17 -5.540700 -3.928933 -0.160000  3.758403
# 1        2018-01-01 00:00:01  0.17 -5.533348 -3.942693 -0.150167  3.760681
# 2        2018-01-01 00:00:02  0.16 -5.525997 -3.956453 -0.140333  3.762957
# 3        2018-01-01 00:00:03  0.19 -5.518645 -3.970213 -0.130500  3.765232
# 4        2018-01-01 00:00:04  0.15 -5.511293 -3.983973 -0.120667  3.767506
# ...                      ...   ...       ...       ...       ...       ...
# 30786169 2018-12-31 23:59:55  0.10  2.842267  2.100433 -3.306100  0.636423
# 30786170 2018-12-31 23:59:56  0.14  2.840353  2.101353 -3.307660  0.636955
# 30786171 2018-12-31 23:59:57  0.12  2.838440  2.102273 -3.309220  0.637486
# 30786172 2018-12-31 23:59:58  0.10  2.836527  2.103193 -3.310780  0.638018
# 30786173 2018-12-31 23:59:59  0.14  2.834613  2.104113 -3.312340  0.638550
#
# ...

# %%
dfw = dfw[dfw['seconds'] <= 0]

# %%
dfw
# Out:
#                     Datetime   gic      Bz        By      Bx     clock  \
# 0        2018-01-01 00:00:00  0.17 -5.5407 -3.928933 -0.1600  3.758403
# 60       2018-01-01 00:01:00  0.17 -5.0996 -4.754533  0.4300  3.891988
# 120      2018-01-01 00:02:00  0.22 -4.6552 -5.393200  0.9440  4.000304
# 180      2018-01-01 00:03:00  0.13 -4.5236 -5.666800  1.1748  4.038708
# 240      2018-01-01 00:04:00  0.09 -4.4976 -5.764000  1.2908  4.049781
# ...                      ...   ...     ...       ...     ...       ...
# 30785874 2018-12-31 23:55:00  0.09  3.3244  1.748000 -2.6244  0.484081
# 30785934 2018-12-31 23:56:00  0.10  3.2607  1.786500 -2.7931  0.501221
# 30785994 2018-12-31 23:57:00  0.09  3.1755  1.885833 -2.9407  0.535900
# 30786054 2018-12-31 23:58:00  0.11  3.0707  1.974233 -3.1003  0.571386
# 30786114 2018-12-31 23:59:00  0.12  2.9475  2.049833 -3.2203  0.607664
#
#                 AE      SymH         Vsw        Dsw       Psw       newell  \
# ...

# %%
dfw.set_index('Datetime')
dfw = dfw.reset_index(drop=True)

# %%
dfw = dfw.set_index('Datetime')

# %%
dfw
# Out:
#                       gic      Bz        By      Bx     clock        AE  \
# Datetime
# 2018-01-01 00:00:00  0.17 -5.5407 -3.928933 -0.1600  3.758403    285.25
# 2018-01-01 00:01:00  0.17 -5.0996 -4.754533  0.4300  3.891988    290.68
# 2018-01-01 00:02:00  0.22 -4.6552 -5.393200  0.9440  4.000304    294.20
# 2018-01-01 00:03:00  0.13 -4.5236 -5.666800  1.1748  4.038708    290.64
# 2018-01-01 00:04:00  0.09 -4.4976 -5.764000  1.2908  4.049781    284.76
# ...                   ...     ...       ...     ...       ...       ...
# 2018-12-31 23:55:00  0.09  3.3244  1.748000 -2.6244  0.484081 -99999.99
# 2018-12-31 23:56:00  0.10  3.2607  1.786500 -2.7931  0.501221 -99999.99
# 2018-12-31 23:57:00  0.09  3.1755  1.885833 -2.9407  0.535900 -99999.99
# 2018-12-31 23:58:00  0.11  3.0707  1.974233 -3.1003  0.571386 -99999.99
# 2018-12-31 23:59:00  0.12  2.9475  2.049833 -3.2203  0.607664 -99999.99
#
#                          SymH         Vsw        Dsw       Psw       newell  \
# Datetime
# ...

# %%
dfw.drop(['seconds'], axis=1)
# Out:
#                       gic      Bz        By      Bx     clock        AE  \
# Datetime
# 2018-01-01 00:00:00  0.17 -5.5407 -3.928933 -0.1600  3.758403    285.25
# 2018-01-01 00:01:00  0.17 -5.0996 -4.754533  0.4300  3.891988    290.68
# 2018-01-01 00:02:00  0.22 -4.6552 -5.393200  0.9440  4.000304    294.20
# 2018-01-01 00:03:00  0.13 -4.5236 -5.666800  1.1748  4.038708    290.64
# 2018-01-01 00:04:00  0.09 -4.4976 -5.764000  1.2908  4.049781    284.76
# ...                   ...     ...       ...     ...       ...       ...
# 2018-12-31 23:55:00  0.09  3.3244  1.748000 -2.6244  0.484081 -99999.99
# 2018-12-31 23:56:00  0.10  3.2607  1.786500 -2.7931  0.501221 -99999.99
# 2018-12-31 23:57:00  0.09  3.1755  1.885833 -2.9407  0.535900 -99999.99
# 2018-12-31 23:58:00  0.11  3.0707  1.974233 -3.1003  0.571386 -99999.99
# 2018-12-31 23:59:00  0.12  2.9475  2.049833 -3.2203  0.607664 -99999.99
#
#                          SymH         Vsw        Dsw       Psw       newell
# Datetime
# ...

# %%
df3 = pd.read_csv(r'C:\Users\cgree\Documents\Astra\Space_weather5_22\2018_sm_reg.csv')
df3 = df3.set_index('Date_UTC')
df3
# Out:
#                      SMEr00  SMEr01  SMEr02  SMEr03  SMEr04  SMEr05  SMEr06  \
# Date_UTC
# 2018-01-01 00:00:00     218     220     220     220      85      85      85
# 2018-01-01 00:01:00     220     220     214     211      88      88      88
# 2018-01-01 00:02:00     220     220     212     207      81      81      81
# 2018-01-01 00:03:00     220     220     212     206      70      70      70
# 2018-01-01 00:04:00     220     220     212     210      53      53      53
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2018-12-31 23:55:00      49      49      35      29       9       9       9
# 2018-12-31 23:56:00      37      37      35      28      11      11      11
# 2018-12-31 23:57:00      64      65      30      30      13      13      13
# 2018-12-31 23:58:00     125     131      31      31      12      12      12
# 2018-12-31 23:59:00     137     137      36      31      13      13      13
#
# ...

# %%
df_merged = dfw.merge(df3, how='outer', left_index=True, right_index=True)

# %%
df_merged
# Out:
#                       gic      Bz        By      Bx     clock        AE  \
# 2018-01-01 00:00:00  0.17 -5.5407 -3.928933 -0.1600  3.758403    285.25
# 2018-01-01 00:01:00  0.17 -5.0996 -4.754533  0.4300  3.891988    290.68
# 2018-01-01 00:02:00  0.22 -4.6552 -5.393200  0.9440  4.000304    294.20
# 2018-01-01 00:03:00  0.13 -4.5236 -5.666800  1.1748  4.038708    290.64
# 2018-01-01 00:04:00  0.09 -4.4976 -5.764000  1.2908  4.049781    284.76
# ...                   ...     ...       ...     ...       ...       ...
# 2018-12-31 23:55:00  0.09  3.3244  1.748000 -2.6244  0.484081 -99999.99
# 2018-12-31 23:56:00  0.10  3.2607  1.786500 -2.7931  0.501221 -99999.99
# 2018-12-31 23:57:00  0.09  3.1755  1.885833 -2.9407  0.535900 -99999.99
# 2018-12-31 23:58:00  0.11  3.0707  1.974233 -3.1003  0.571386 -99999.99
# 2018-12-31 23:59:00  0.12  2.9475  2.049833 -3.2203  0.607664 -99999.99
#
#                          SymH         Vsw        Dsw       Psw  ...  GSM_By  \
# ...

# %%
compression_opts = dict(method='zip',
                        archive_name='master_weakly_2018.csv')  
df_merged.to_csv('master_weakly_2018.zip', index=True,
          compression=compression_opts)

# %%
#df_merged = pd.read_csv(r'weakly_2018.zip', compression='zip')
