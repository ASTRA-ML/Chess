# %%
import pandas as pd
import os
import numpy as np

# %%
df = pd.DataFrame()
df2 = pd.DataFrame()
df_merged_gic = pd.DataFrame()
df_merged = pd.DataFrame()

# %%
df_merged = pd.read_csv(r'master_weakly_2018.zip', compression='zip')

# %%
df_merged.columns
# Out:
# Index(['Unnamed: 0', 'gic', 'Bz', 'By', 'Bx', 'clock', 'AE', 'SymH', 'Vsw',
#        'Dsw', 'Psw', 'newell', 'seconds', 'SMEr00', 'SMEr01', 'SMEr02',
#        'SMEr03', 'SMEr04', 'SMEr05', 'SMEr06', 'SMEr07', 'SMEr08', 'SMEr09',
#        'SMEr10', 'SMEr11', 'SMEr12', 'SMEr13', 'SMEr14', 'SMEr15', 'SMEr16',
#        'SMEr17', 'SMEr18', 'SMEr19', 'SMEr20', 'SMEr21', 'SMEr22', 'SMEr23',
#        'SMLr00', 'SMLr01', 'SMLr02', 'SMLr03', 'SMLr04', 'SMLr05', 'SMLr06',
#        'SMLr07', 'SMLr08', 'SMLr09', 'SMLr10', 'SMLr11', 'SMLr12', 'SMLr13',
#        'SMLr14', 'SMLr15', 'SMLr16', 'SMLr17', 'SMLr18', 'SMLr19', 'SMLr20',
#        'SMLr21', 'SMLr22', 'SMLr23', 'SMUr00', 'SMUr01', 'SMUr02', 'SMUr03',
#        'SMUr04', 'SMUr05', 'SMUr06', 'SMUr07', 'SMUr08', 'SMUr09', 'SMUr10',
#        'SMUr11', 'SMUr12', 'SMUr13', 'SMUr14', 'SMUr15', 'SMUr16', 'SMUr17',
#        'SMUr18', 'SMUr19', 'SMUr20', 'SMUr21', 'SMUr22', 'SMUr23', 'SMR00',
# ...

# %%
df_merged['Datetime'] = df_merged['Unnamed: 0']

# %%
df_merged
# Out:
#                  Unnamed: 0   gic      Bz        By      Bx     clock  \
# 0       2018-01-01 00:00:00  0.17 -5.5407 -3.928933 -0.1600  3.758403
# 1       2018-01-01 00:01:00  0.17 -5.0996 -4.754533  0.4300  3.891988
# 2       2018-01-01 00:02:00  0.22 -4.6552 -5.393200  0.9440  4.000304
# 3       2018-01-01 00:03:00  0.13 -4.5236 -5.666800  1.1748  4.038708
# 4       2018-01-01 00:04:00  0.09 -4.4976 -5.764000  1.2908  4.049781
# ...                     ...   ...     ...       ...     ...       ...
# 525595  2018-12-31 23:55:00  0.09  3.3244  1.748000 -2.6244  0.484081
# 525596  2018-12-31 23:56:00  0.10  3.2607  1.786500 -2.7931  0.501221
# 525597  2018-12-31 23:57:00  0.09  3.1755  1.885833 -2.9407  0.535900
# 525598  2018-12-31 23:58:00  0.11  3.0707  1.974233 -3.1003  0.571386
# 525599  2018-12-31 23:59:00  0.12  2.9475  2.049833 -3.2203  0.607664
#
#               AE      SymH         Vsw        Dsw  ...  GSM_Bz    GSE_Vx  \
# ...

# %%
df2 = df_merged.set_index('Datetime')

# %%
df2
# Out:
#                               Unnamed: 0   gic      Bz        By      Bx  \
# Datetime
# 2018-01-01 00:00:00  2018-01-01 00:00:00  0.17 -5.5407 -3.928933 -0.1600
# 2018-01-01 00:01:00  2018-01-01 00:01:00  0.17 -5.0996 -4.754533  0.4300
# 2018-01-01 00:02:00  2018-01-01 00:02:00  0.22 -4.6552 -5.393200  0.9440
# 2018-01-01 00:03:00  2018-01-01 00:03:00  0.13 -4.5236 -5.666800  1.1748
# 2018-01-01 00:04:00  2018-01-01 00:04:00  0.09 -4.4976 -5.764000  1.2908
# ...                                  ...   ...     ...       ...     ...
# 2018-12-31 23:55:00  2018-12-31 23:55:00  0.09  3.3244  1.748000 -2.6244
# 2018-12-31 23:56:00  2018-12-31 23:56:00  0.10  3.2607  1.786500 -2.7931
# 2018-12-31 23:57:00  2018-12-31 23:57:00  0.09  3.1755  1.885833 -2.9407
# 2018-12-31 23:58:00  2018-12-31 23:58:00  0.11  3.0707  1.974233 -3.1003
# 2018-12-31 23:59:00  2018-12-31 23:59:00  0.12  2.9475  2.049833 -3.2203
#
#                         clock        AE      SymH         Vsw        Dsw  ...  \
# ...

# %%
df_merged = df2.drop(['Unnamed: 0'], axis=1)

# %%
df_merged
# Out:
#                       gic      Bz        By      Bx     clock        AE  \
# Datetime
# 2018-01-01 00:00:00  0.17 -5.5407 -3.928933 -0.1600  3.758403    285.25
# 2018-01-01 00:01:00  0.17 -5.0996 -4.754533  0.4300  3.891988    290.68
# 2018-01-01 00:02:00  0.22 -4.6552 -5.393200  0.9440  4.000304    294.20
# 2018-01-01 00:03:00  0.13 -4.5236 -5.666800  1.1748  4.038708    290.64
# 2018-01-01 00:04:00  0.09 -4.4976 -5.764000  1.2908  4.049781    284.76
# ...                   ...     ...       ...     ...       ...       ...
# 2018-12-31 23:55:00  0.09  3.3244  1.748000 -2.6244  0.484081 -99999.99
# 2018-12-31 23:56:00  0.10  3.2607  1.786500 -2.7931  0.501221 -99999.99
# 2018-12-31 23:57:00  0.09  3.1755  1.885833 -2.9407  0.535900 -99999.99
# 2018-12-31 23:58:00  0.11  3.0707  1.974233 -3.1003  0.571386 -99999.99
# 2018-12-31 23:59:00  0.12  2.9475  2.049833 -3.2203  0.607664 -99999.99
#
#                          SymH         Vsw        Dsw       Psw  ...  GSM_By  \
# ...

# %%
df_merged_gic
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_merged_gic['gic'] = df_merged['gic']
# df_merged_gic['gic'] = df_merged.drop(['gic'], axis=1)

# %%
df_merged_gic = df_merged_gic.replace([99999.9, 9999.99, 999.99, 999999.0 ,999999.00,-99999.990000,-99999.990000, '#REF!',np.nan ], 0)

# %%
df_merged_gic
# Out:
#                       gic
# Datetime
# 2018-01-01 00:00:00  0.17
# 2018-01-01 00:01:00  0.17
# 2018-01-01 00:02:00  0.22
# 2018-01-01 00:03:00  0.13
# 2018-01-01 00:04:00  0.09
# ...                   ...
# 2018-12-31 23:55:00  0.09
# 2018-12-31 23:56:00  0.10
# 2018-12-31 23:57:00  0.09
# 2018-12-31 23:58:00  0.11
# 2018-12-31 23:59:00  0.12
#
# [525600 rows x 1 columns]

# %%
df_merged_gic.describe()
# Out:
#                  gic
# count  525600.000000
# mean        0.003133
# std         0.184809
# min        -9.220000
# 25%        -0.080000
# 50%         0.010000
# 75%         0.090000
# max         4.700000

# %%
df_merged_gic.columns
# Out:
# Index(['gic'], dtype='object')

# %%
df_merged_gic = df_merged_gic.drop(['principal component 1','principal component 2', 'principal component 3'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-ec76c03b9cd6> in <module>
# ----> 1 df_merged_gic = df_merged_gic.drop(['principal component 1','principal component 2', 'principal component 3'], axis=1)
#
# F:\Astra\conda2\envs\Austin\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3992             level=level,
#    3993             inplace=inplace,
# -> 3994             errors=errors,
#    3995         )
#    3996
#
# F:\Astra\conda2\envs\Austin\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3933         for axis, labels in axes.items():
#    3934             if labels is not None:
# -> 3935                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3936
#    3937         if inplace:
#
# ...

# %%
df_merged_gic
# Out:
#                       gic
# Datetime
# 2018-01-01 00:00:00  0.17
# 2018-01-01 00:01:00  0.17
# 2018-01-01 00:02:00  0.22
# 2018-01-01 00:03:00  0.13
# 2018-01-01 00:04:00  0.09
# ...                   ...
# 2018-12-31 23:55:00  0.09
# 2018-12-31 23:56:00  0.10
# 2018-12-31 23:57:00  0.09
# 2018-12-31 23:58:00  0.11
# 2018-12-31 23:59:00  0.12
#
# [525600 rows x 1 columns]

# %%
df_merged = df_merged.replace([99999.9, 9999.99, 999.99, 999999.0 ,999999.00,-99999.990000,-99999.990000, '#REF!',np.nan ], 0)

# %%
df_merged.describe()
# Out:
#                  gic             Bz             By             Bx  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        0.003133      -0.098035      -0.405388       0.151692
# std         0.184809       2.332359       2.944742       2.895380
# min        -9.220000     -20.159200     -17.249200     -15.024000
# 25%        -0.080000      -1.313600      -2.306800      -1.930000
# 50%         0.010000       0.000000      -0.133267       0.000000
# 75%         0.090000       1.190000       1.484800       2.272400
# max         4.700000      15.259600      18.298400      13.947200
#
#                clock             AE           SymH            Vsw  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        3.076170      17.234646      -6.446583     374.198593
# std         1.888315      63.196621      12.762283     141.655918
# min         0.000000       0.000000    -204.240000       0.000000
# ...

# %%
df_merged.drop(['gic'], axis=1)
# Out:
#                          Bz        By      Bx     clock      AE      SymH  \
# Datetime
# 2018-01-01 00:00:00 -5.5407 -3.928933 -0.1600  3.758403  285.25 -3.640000
# 2018-01-01 00:01:00 -5.0996 -4.754533  0.4300  3.891988  290.68 -4.760000
# 2018-01-01 00:02:00 -4.6552 -5.393200  0.9440  4.000304  294.20 -5.960000
# 2018-01-01 00:03:00 -4.5236 -5.666800  1.1748  4.038708  290.64 -6.600000
# 2018-01-01 00:04:00 -4.4976 -5.764000  1.2908  4.049781  284.76 -7.080000
# ...                     ...       ...     ...       ...     ...       ...
# 2018-12-31 23:55:00  3.3244  1.748000 -2.6244  0.484081    0.00 -4.160000
# 2018-12-31 23:56:00  3.2607  1.786500 -2.7931  0.501221    0.00 -4.260000
# 2018-12-31 23:57:00  3.1755  1.885833 -2.9407  0.535900    0.00 -4.393333
# 2018-12-31 23:58:00  3.0707  1.974233 -3.1003  0.571386    0.00 -4.233333
# 2018-12-31 23:59:00  2.9475  2.049833 -3.2203  0.607664    0.00 -4.033333
#
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(df_merged)
principalDf2 = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3'])

# %%
principalDf2
# Out:
#         principal component 1  principal component 2  principal component 3
# 0                 2522.722352            4980.099206              40.021187
# 1                 6791.115197           -1006.520481            -115.982313
# 2                 6506.883006           -1160.397033            -101.734742
# 3                 6644.695906           -1427.581950            -119.780090
# 4                 6574.535937           -1321.890212            -131.641522
# ...                       ...                    ...                    ...
# 525595           -3719.834045            -364.708532             -24.776885
# 525596           -3904.253743             -82.410442             -24.772698
# 525597           -3864.619447             -52.205333              12.987469
# 525598           -3819.373993             -18.662053              99.533414
# 525599           -3774.145927              17.082347             103.482732
#
# [525600 rows x 3 columns]

# %%
df_merged_gic = df_merged_gic.reset_index()

# %%
df_merged_gic
# Out:
#                    Datetime   gic
# 0       2018-01-01 00:00:00  0.17
# 1       2018-01-01 00:01:00  0.17
# 2       2018-01-01 00:02:00  0.22
# 3       2018-01-01 00:03:00  0.13
# 4       2018-01-01 00:04:00  0.09
# ...                     ...   ...
# 525595  2018-12-31 23:55:00  0.09
# 525596  2018-12-31 23:56:00  0.10
# 525597  2018-12-31 23:57:00  0.09
# 525598  2018-12-31 23:58:00  0.11
# 525599  2018-12-31 23:59:00  0.12
#
# [525600 rows x 2 columns]

# %%
df_merged_gic = df_merged_gic.merge(principalDf2, how='outer', left_index=True, right_index=True)

# %%
df_merged_gic
# Out:
#                    Datetime   gic  principal component 1  \
# 0       2018-01-01 00:00:00  0.17            2522.722352
# 1       2018-01-01 00:01:00  0.17            6791.115197
# 2       2018-01-01 00:02:00  0.22            6506.883006
# 3       2018-01-01 00:03:00  0.13            6644.695906
# 4       2018-01-01 00:04:00  0.09            6574.535937
# ...                     ...   ...                    ...
# 525595  2018-12-31 23:55:00  0.09           -3719.834045
# 525596  2018-12-31 23:56:00  0.10           -3904.253743
# 525597  2018-12-31 23:57:00  0.09           -3864.619447
# 525598  2018-12-31 23:58:00  0.11           -3819.373993
# 525599  2018-12-31 23:59:00  0.12           -3774.145927
#
#         principal component 2  principal component 3
# 0                 4980.099206              40.021187
# 1                -1006.520481            -115.982313
# 2                -1160.397033            -101.734742
# 3                -1427.581950            -119.780090
# ...

# %%
df_merged_gic = df_merged_gic.set_index('Datetime')
# df_merged_gic = df_merged_gic.reset_index(drop=True)

# %%
df_merged_gic
# Out:
#                       gic  principal component 1  principal component 2  \
# Datetime
# 2018-01-01 00:00:00  0.17            2522.722352            4980.099206
# 2018-01-01 00:01:00  0.17            6791.115197           -1006.520481
# 2018-01-01 00:02:00  0.22            6506.883006           -1160.397033
# 2018-01-01 00:03:00  0.13            6644.695906           -1427.581950
# 2018-01-01 00:04:00  0.09            6574.535937           -1321.890212
# ...                   ...                    ...                    ...
# 2018-12-31 23:55:00  0.09           -3719.834045            -364.708532
# 2018-12-31 23:56:00  0.10           -3904.253743             -82.410442
# 2018-12-31 23:57:00  0.09           -3864.619447             -52.205333
# 2018-12-31 23:58:00  0.11           -3819.373993             -18.662053
# 2018-12-31 23:59:00  0.12           -3774.145927              17.082347
#
#                      principal component 3
# Datetime
# ...

# %%
compression_opts = dict(method='zip',
                        archive_name='pca_weakly_2018.csv')  
df_merged_gic.to_csv('pca_weakly_2018.zip', index=True,
          compression=compression_opts)
